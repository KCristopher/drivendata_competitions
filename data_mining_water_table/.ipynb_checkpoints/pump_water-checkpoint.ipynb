# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from random import randrange
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import log_loss
from datetime import datetime
import autosklearn.classification
from sklearn.metrics import ConfusionMatrixDisplay
from joblib import dump
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
import sys
sys.path.append('/home/krzysiek/drivendata/drivendata_competitions/functions')
from eda_automations import *
from sklearn.model_selection import train_test_split
import random as r
from statsmodels.distributions.empirical_distribution import ECDF
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('https://s3.amazonaws.com/drivendata/data/7/public/4910797b-ee55-40a7-8668-10efd5c1b960.csv')

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe

# %%
labels_data = pd.read_csv('https://github.com/KCristopher/drivendata_competitions/raw/main/data/training_set_labels.csv')

# %%
labels_data.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %% [markdown]
# The data contains the info about waterpoints in Tanzania. Each observations correspond to some waterpoint and is described in terms of the variables such as the height at which the waterpoint is located, type of source of the water (for example rain or spring) or the institution which built the well.

# %% [markdown]
# We hope that we would be able to discern which waterponits are functional, which are not, and which needs to be repaired by examining the levels of all these different variables.

# %%
labels_data.index = labels_data['id']
del labels_data['id']

# %%
labels_data.head(3)
# Out:
#       status_group
# id
# 69572   functional
# 8776    functional
# 34310   functional

# %%
y = labels_data.copy()
X = df.copy()

# %% [markdown]
# Splitting the data into training and testing sets :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %% [markdown]
# <center>Exploring training data</center>

# %% [markdown]
# <center>Checking the general structure of the data, data types and  missing values :</center>

# %%
summarize_df(X_train)
# Out:
# Glance at the data :
#           id  amount_tsh date_recorded      funder  gps_height installer  \
# 44928  31080         0.0    2012-10-10         Dwe           0    WEDECO
# 31178  17282        50.0    2013-02-16       Jaica         -33     Tasaf
# 9485   72545         0.0    2011-03-20         Dhv         298       DWE
# 955    44490         0.0    2012-10-12       Rwssp           0     RWSSP
# 29186  67816         5.0    2013-02-04  Ces (gmbh)        1088       DWE
#
#        longitude   latitude                 wpt_name  num_private  \
# 44928  33.179596  -4.214966                Hospitali            0
# 31178  40.322805 -10.456297        Kwa Bakari Ismail            0
# 9485   36.353508  -8.780099            Kwa Mgirigiti            0
# 955    33.071249  -3.803178                   Ujamaa            0
# 29186  37.271938  -3.283501  Kwa Richard Simon Chami            0
#
#                          basin  subvillage       region  region_code  \
# 44928                 Internal     Majengo       Tabora           14
# 31178  Ruvuma / Southern Coast     Kipingo       Mtwara           99
# 9485                    Rufiji  Kilungwili     Morogoro            5
# 955              Lake Victoria      Busubi    Shinyanga           17
# 29186                  Pangani      Muyuni  Kilimanjaro            3
#
#        district_code              lga         ward  population public_meeting  \
# 44928              1            Nzega  Nzega Urban           0          False
# 31178              1     Mtwara Rural    Mahurunga        1000           True
# 9485               4           Ulanga     Mtimbira           1           True
# 955                3  Shinyanga Rural        Didia           0           True
# 29186              4      Moshi Rural        Kindi          50           True
#
#                    recorded_by scheme_management                  scheme_name  \
# 44928  GeoData Consultants Ltd   Water authority        Kilimi and uchama dam
# 31178  GeoData Consultants Ltd               VWC         Tangazo water supply
# 9485   GeoData Consultants Ltd               NaN                          NaN
# 955    GeoData Consultants Ltd               WUG                          NaN
# 29186  GeoData Consultants Ltd       Water Board  Lyamungo umbwe water supply
#
#       permit  construction_year extraction_type extraction_type_group  \
# 44928   True                  0             ksb           submersible
# 31178   True               2008     submersible           submersible
# 9485    True               1991           other                 other
# 955     True                  0           other                 other
# 29186   True               2007         gravity               gravity
#
#       extraction_type_class       management management_group         payment  \
# 44928           submersible  water authority       commercial  pay per bucket
# 31178           submersible              vwc       user-group  pay per bucket
# 9485                  other              wug       user-group       never pay
# 955                   other              wug       user-group       never pay
# 29186               gravity      water board       user-group  pay per bucket
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# 44928   per bucket      coloured       colored  insufficient   insufficient
# 31178   per bucket         salty         salty        enough         enough
# 9485     never pay          soft          good  insufficient   insufficient
# 955      never pay          soft          good        enough         enough
# 29186   per bucket          soft          good        enough         enough
#
#              source   source_type source_class              waterpoint_type  \
# 44928           dam           dam      surface                          dam
# 31178   machine dbh      borehole  groundwater  communal standpipe multiple
# 9485   shallow well  shallow well  groundwater                        other
# 955    shallow well  shallow well  groundwater                        other
# 29186         river    river/lake      surface           communal standpipe
#
#       waterpoint_type_group
# 44928                   dam
# 31178    communal standpipe
# 9485                  other
# 955                   other
# 29186    communal standpipe
# Data types, dimension of the data :
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53460 entries, 44928 to 56422
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     53460 non-null  int64
#  1   amount_tsh             53460 non-null  float64
#  2   date_recorded          53460 non-null  object
#  3   funder                 50179 non-null  object
#  4   gps_height             53460 non-null  int64
#  5   installer              50160 non-null  object
#  6   longitude              53460 non-null  float64
#  7   latitude               53460 non-null  float64
#  8   wpt_name               53460 non-null  object
#  9   num_private            53460 non-null  int64
#  10  basin                  53460 non-null  object
#  11  subvillage             53132 non-null  object
#  12  region                 53460 non-null  object
#  13  region_code            53460 non-null  int64
#  14  district_code          53460 non-null  int64
#  15  lga                    53460 non-null  object
#  16  ward                   53460 non-null  object
#  17  population             53460 non-null  int64
#  18  public_meeting         50466 non-null  object
#  19  recorded_by            53460 non-null  object
#  20  scheme_management      49992 non-null  object
#  21  scheme_name            28152 non-null  object
#  22  permit                 50706 non-null  object
#  23  construction_year      53460 non-null  int64
#  24  extraction_type        53460 non-null  object
#  25  extraction_type_group  53460 non-null  object
#  26  extraction_type_class  53460 non-null  object
#  27  management             53460 non-null  object
#  28  management_group       53460 non-null  object
#  29  payment                53460 non-null  object
#  30  payment_type           53460 non-null  object
#  31  water_quality          53460 non-null  object
#  32  quality_group          53460 non-null  object
#  33  quantity               53460 non-null  object
#  34  quantity_group         53460 non-null  object
#  35  source                 53460 non-null  object
#  36  source_type            53460 non-null  object
#  37  source_class           53460 non-null  object
#  38  waterpoint_type        53460 non-null  object
#  39  waterpoint_type_group  53460 non-null  object
# dtypes: float64(3), int64(7), object(30)
# memory usage: 16.7+ MB
# None
# Missing values across variables :
# scheme_name              25308
# scheme_management         3468
# installer                 3300
# funder                    3281
# public_meeting            2994
# permit                    2754
# subvillage                 328
# management_group             0
# waterpoint_type              0
# extraction_type              0
# extraction_type_group        0
# source_class                 0
# extraction_type_class        0
# management                   0
# source_type                  0
# source                       0
# payment_type                 0
# water_quality                0
# construction_year            0
# quality_group                0
# quantity                     0
# quantity_group               0
# payment                      0
# id                           0
# amount_tsh                   0
# recorded_by                  0
# population                   0
# ward                         0
# lga                          0
# district_code                0
# region_code                  0
# region                       0
# basin                        0
# num_private                  0
# wpt_name                     0
# latitude                     0
# longitude                    0
# gps_height                   0
# date_recorded                0
# waterpoint_type_group        0
# dtype: int64
# Missing values - % of the data :
# scheme_name              47.34
# scheme_management         6.49
# installer                 6.17
# funder                    6.14
# public_meeting            5.60
# permit                    5.15
# subvillage                0.61
# management_group          0.00
# waterpoint_type           0.00
# extraction_type           0.00
# extraction_type_group     0.00
# source_class              0.00
# extraction_type_class     0.00
# management                0.00
# source_type               0.00
# source                    0.00
# payment_type              0.00
# water_quality             0.00
# construction_year         0.00
# quality_group             0.00
# quantity                  0.00
# quantity_group            0.00
# payment                   0.00
# id                        0.00
# amount_tsh                0.00
# recorded_by               0.00
# population                0.00
# ward                      0.00
# lga                       0.00
# district_code             0.00
# region_code               0.00
# region                    0.00
# basin                     0.00
# num_private               0.00
# wpt_name                  0.00
# latitude                  0.00
# longitude                 0.00
# gps_height                0.00
# date_recorded             0.00
# waterpoint_type_group     0.00
# dtype: float64

# %%
codes = [c for c in X_train.columns if 'code' in c]
codes
# Out:
# ['region_code', 'district_code']

# %% [markdown]
# <center>Getting numeric summaries of the data</center>

# %%
summarize_numeric_data(X_train, exclude = ['id'] + codes)
# Out:
# The correlation between the variables in the dataset :
#                    amount_tsh  gps_height  longitude  latitude  num_private  \
# amount_tsh               1.00        0.08       0.02     -0.05         0.00
# gps_height               0.08        1.00       0.15     -0.04         0.01
# longitude                0.02        0.15       1.00     -0.43         0.02
# latitude                -0.05       -0.04      -0.43      1.00         0.01
# num_private              0.00        0.01       0.02      0.01         1.00
# population               0.01        0.13       0.09     -0.02         0.00
# construction_year        0.07        0.66       0.40     -0.25         0.03
#
#                    population  construction_year
# amount_tsh               0.01               0.07
# gps_height               0.13               0.66
# longitude                0.09               0.40
# latitude                -0.02              -0.25
# num_private              0.00               0.03
# population               1.00               0.26
# construction_year        0.26               1.00
# Descriptive statistics of numeric data :
#        amount_tsh  gps_height  longitude  latitude  num_private  population  \
# count    53460.00    53460.00   53460.00  53460.00     53460.00    53460.00
# mean       316.23      669.11      34.09     -5.71         0.50      179.47
# std       3048.95      693.05       6.55      2.95        12.86      469.42
# min          0.00      -63.00       0.00    -11.65         0.00        0.00
# 25%          0.00        0.00      33.09     -8.55         0.00        0.00
# 50%          0.00      371.00      34.91     -5.02         0.00       25.00
# 75%         20.00     1320.00      37.18     -3.33         0.00      215.00
# max     350000.00     2770.00      40.35     -0.00      1776.00    30500.00
#
#        construction_year
# count           53460.00
# mean             1303.02
# std               950.88
# min                 0.00
# 25%                 0.00
# 50%              1986.00
# 75%              2004.00
# max              2013.00

# %%
look_at_variables_values(X_train)
# Out:
# Unique values from id, limited to 30
#
# 5343     36051
# 13386    61284
# 14036    64929
# 40784    22936
# 51713    59673
# 25423    45698
# 33115    32755
# 9351     31466
# 44869    17286
# 27798    69929
# 12398     6640
# 12541    47065
# 47905    55519
# 27186    25917
# 19550    43229
# 12150    40902
# 19596    26770
# 46399    60631
# 10103    18730
# 24342     7521
# 10123    10779
# 27843    42423
# 12017    33867
# 16790    16880
# 36825    56475
# 9246     24451
# 11267    54590
# 19570    62278
# 48777    51265
# 8244     34420
# dtype: int64
#
#
# Unique values from amount_tsh, limited to 30
#
# 64     11000.00
# 93         0.25
# 32        33.00
# 2          5.00
# 31      2500.00
# 84       590.00
# 60      7500.00
# 63    200000.00
# 66      6300.00
# 20      1000.00
# 69         9.00
# 58      7000.00
# 7       1300.00
# 73         0.20
# 74       520.00
# 47         2.00
# 5       2000.00
# 90    100000.00
# 29       450.00
# 52      8500.00
# 43      2200.00
# 4       1200.00
# 22       750.00
# 10        10.00
# 37     10000.00
# 53     16300.00
# 25        25.00
# 33        60.00
# 27         7.00
# 26      4000.00
# dtype: float64
#
#
# Unique values from date_recorded, limited to 30
#
# 32     2011-07-26
# 29     2011-03-03
# 353    2011-09-19
# 135    2013-09-03
# 296    2012-12-23
# 340    2011-08-28
# 109    2012-10-26
# 203    2013-03-08
# 212    2011-10-07
# 306    2011-08-24
# 154    2011-04-16
# 23     2013-01-31
# 251    2011-04-20
# 2      2011-03-20
# 176    2011-02-21
# 187    2013-12-02
# 190    2013-03-22
# 332    2012-12-12
# 318    2012-11-14
# 57     2013-03-16
# 305    2011-12-07
# 328    2013-07-02
# 5      2011-03-15
# 229    2011-07-05
# 211    2011-02-17
# 307    2013-12-01
# 33     2013-03-27
# 181    2011-01-08
# 162    2011-03-13
# 182    2011-04-06
# dtype: object
#
#
# Unique values from funder, limited to 30
#
# 1456                            Runda
# 345                               Nsc
# 222                            Unesco
# 1292                            Kadip
# 1635                            Lgdbg
# 107                               Snv
# 1247                         Dhv\swis
# 789                             Fabia
# 1033                            Compa
# 725                            Suwasa
# 1257                            Rvemp
# 543                            Bilila
# 1150                           Uniceg
# 371                             Mboma
# 1710                 Water Department
# 350                             U.S.A
# 1535                      Lga And Adb
# 968                              Adap
# 887                            Caltas
# 9                              Tredep
# 1195                          Zinduka
# 138     Halmashauri Ya Wilaya Sikonge
# 1730                         Seronera
# 995                         Pentecost
# 747                    Nipon & Panoco
# 42                            African
# 1128                    Doner And Com
# 1052                             Tove
# 217               Kilindi District Co
# 1452                          W.F.D.P
# dtype: object
#
#
# Unique values from gps_height, limited to 30
#
# 1863     584
# 1086     138
# 544     1275
# 2406    2080
# 131      560
# 1452    1620
# 1724    1055
# 2040     509
# 1678     894
# 1675     772
# 204     1258
# 1270      14
# 976     1780
# 830     1608
# 2064     -59
# 1360    1826
# 378     1987
# 583     1575
# 2082    1881
# 995      839
# 2164     -47
# 2161    2475
# 1012     780
# 2084    2115
# 96       723
# 1590     271
# 1301     650
# 1660     788
# 1770     196
# 695     1199
# dtype: int64
#
#
# Unique values from installer, limited to 30
#
# 458                           Moroil
# 301                            PADEP
# 581                            Mianz
# 1238                   Justine Marwa
# 1974                        SERONERA
# 62         District water department
# 363                          Enyueti
# 336                           CARTAS
# 1679                              MD
# 1433                            ALIA
# 583                         TCRS/DWE
# 514                           MSIKIT
# 1110                            Word
# 1106                 CARTAS Tanzania
# 1169          Wizra ya maji na egypt
# 1041               Unknown Installer
# 728                    IREVEA SISTER
# 1979                            FIDA
# 1086                           Counc
# 1501                              KU
# 187                   TPP TRUSTMOSHI
# 737                           Sumbaw
# 787                            FOLAC
# 4                         Government
# 491                        Raurensia
# 785                         Villaers
# 1135                      mwakalinga
# 720     KARUMBA BUILDING COMPANY LTD
# 858                  anglican Uganda
# 682                 Usambala sisters
# dtype: object
#
#
# Unique values from longitude, limited to 30
#
# 47486    31.613123
# 44155    32.151080
# 10394    36.334665
# 21695    34.711686
# 17888    37.368810
# 47759    39.231064
# 47087    36.128240
# 13786    34.164252
# 20218    37.466809
# 21132    33.619343
# 12706    37.037402
# 19037    38.328262
# 46687    36.263915
# 37935    35.834972
# 16964    36.720572
# 584      32.253637
# 11114    31.988671
# 19584    31.664935
# 7874     33.917056
# 5422     37.056639
# 31516    35.614890
# 28391    35.841652
# 46699    36.688709
# 16833    33.571281
# 28662    39.361010
# 49636    32.801274
# 20719    39.780163
# 3837     36.944834
# 29716    35.435409
# 13272    32.623261
# dtype: float64
#
#
# Unique values from latitude, limited to 30
#
# 10297   -3.223739
# 24440   -5.864503
# 11231   -4.483622
# 38054   -3.356018
# 44081   -3.011773
# 45591   -4.912460
# 12113   -5.998872
# 28448   -4.949764
# 19746   -6.829642
# 34733   -9.056799
# 25086   -9.394950
# 4561    -4.357027
# 38051   -8.136121
# 20224   -9.235391
# 5502    -3.276019
# 9696    -3.274850
# 25130   -3.563106
# 26398   -3.874396
# 45304   -4.783620
# 10745   -5.971887
# 31939   -9.199427
# 20439   -3.321813
# 30164   -7.764620
# 15673   -5.536306
# 7998    -2.559759
# 25850   -6.115563
# 18744   -3.228073
# 43351   -6.913913
# 42941   -4.488624
# 962     -6.084898
# dtype: float64
#
#
# Unique values from wpt_name, limited to 30
#
# 23618              Kwa Zumberi Hassani
# 33615                      Kwa Lusanya
# 33570                         Imonelwa
# 3435                           Kambini
# 11069                    Kwa Nyansakya
# 30979                       Kwa Kamoti
# 1587                  Mzee Labani Sawe
# 19058                 Kwa Lugano Mjota
# 28388                Masangura Dp Mo.9
# 1500              Kwa Josephat Kidinji
# 21003                          Mnazini
# 29311                 Kwa Mungo Kabasa
# 24813                     Saidi Muleka
# 9474                      Ramson Nzowa
# 6767                           Folac B
# 1560               Kwa Vurumensi Mremi
# 10112                        Nyalubezi
# 5743                          Uholanzi
# 12409                        Hailosi B
# 20654              Mzee Masande Kalima
# 17744                        Vumanga B
# 26183                       Ilaramatak
# 2158     Musati Primary School Dp No.7
# 33529                       Kwa Sidile
# 20625              Kwa Khamisi Ismaili
# 4612                  Kwa Mzee Rumbasi
# 10848           Kwa Machson Mwakibwaga
# 3532             Kwa Hussein Msalamala
# 7506                         Serengeti
# 1445                           Ringini
# dtype: object
#
#
# Unique values from num_private, limited to 30
#
# 37     26
# 51     14
# 39      7
# 13     39
# 11     93
# 36      2
# 62    180
# 30     27
# 21    102
# 60    672
# 28    450
# 26     25
# 43    213
# 9      45
# 58     30
# 46    141
# 23      9
# 45     22
# 27     20
# 63     60
# 53     55
# 1      87
# 16     15
# 4       4
# 20      3
# 40    111
# 33     38
# 56     62
# 15     80
# 32     10
# dtype: int64
#
#
# Unique values from basin, limited to 30
#
# 0                   Internal
# 5                 Lake Nyasa
# 2                     Rufiji
# 7            Lake Tanganyika
# 4                    Pangani
# 1    Ruvuma / Southern Coast
# 8                 Lake Rukwa
# 6                Wami / Ruvu
# 3              Lake Victoria
# dtype: object
#
#
# Unique values from subvillage, limited to 30
#
# 16969        Bukulungila
# 7490            Kilimbei
# 14669         Junjuiseke
# 3767            Mitaloni
# 5941              Kilema
# 5282            Jamuhuri
# 6624            Mwabenda
# 8261             Mwigama
# 12206           Mukibira
# 5399               Beila
# 17403           Kumlengo
# 13981    Nyamahanga Kati
# 10348           Marahala
# 13063            Mwahuga
# 5180             Mkirago
# 11135            Lusembo
# 16415     Mabira Station
# 3468        Itikangombwe
# 11676           Makome B
# 14310          Emututoto
# 908          Uswahhilini
# 9867           Kwasahani
# 6857         Mwakuenga A
# 11737          Kwalakamu
# 16705           Sukuma B
# 2981           Kwalubuye
# 9317            Lyelembo
# 12801          Magodauni
# 15603          Kyamshoga
# 711              Kiselya
# dtype: object
#
#
# Unique values from region, limited to 30
#
# 7             Mbeya
# 16           Kagera
# 17            Lindi
# 11          Singida
# 10           Iringa
# 20    Dar es Salaam
# 18             Mara
# 12            Pwani
# 13            Rukwa
# 15           Kigoma
# 8            Arusha
# 14           Dodoma
# 6            Mwanza
# 4       Kilimanjaro
# 9            Ruvuma
# 2          Morogoro
# 19          Manyara
# 0            Tabora
# 5             Tanga
# 3         Shinyanga
# 1            Mtwara
# dtype: object
#
#
# Unique values from region_code, limited to 30
#
# 13    15
# 3     17
# 24    60
# 11    13
# 5      4
# 2      5
# 8      2
# 21     7
# 25    24
# 7     12
# 17    80
# 16    18
# 14     1
# 6     19
# 26    40
# 12     6
# 9     10
# 19    21
# 22     8
# 20     9
# 18    20
# 4      3
# 15    16
# 0     14
# 10    11
# 23    90
# 1     99
# dtype: int64
#
#
# Unique values from district_code, limited to 30
#
# 14    60
# 3      8
# 19    80
# 18     0
# 6      7
# 4      6
# 9     43
# 7      2
# 11    33
# 10    53
# 13    30
# 16    67
# 17    63
# 5      5
# 15    23
# 2      3
# 8     13
# 12    62
# 1      4
# 0      1
# dtype: int64
#
#
# Unique values from lga, limited to 30
#
# 12             Tunduru
# 86               Mbozi
# 112            Sikonge
# 107              Meatu
# 67               Mafia
# 2               Ulanga
# 0                Nzega
# 3      Shinyanga Rural
# 91               Ngara
# 58           Serengeti
# 79          Ngorongoro
# 43             Lushoto
# 81         Lindi Urban
# 87        Iringa Rural
# 19              Rungwe
# 99              Kilolo
# 18               Nkasi
# 44        Musoma Rural
# 73              Masasi
# 68             Bukombe
# 48             Ukerewe
# 95                Bahi
# 52            Namtumbo
# 103       Arusha Urban
# 121             Hanang
# 42             Kishapu
# 55             Mufindi
# 4          Moshi Rural
# 33               Kilwa
# 115              Tanga
# dtype: object
#
#
# Unique values from ward, limited to 30
#
# 1068         Oltrumet
# 1997          Muhutwe
# 156            Ntwike
# 1390    Mlowa Bwawani
# 188              Poli
# 1566        Kwaluguru
# 143            Matola
# 16               Puma
# 1833         Kilomeni
# 1931          Bassotu
# 1437           Irisya
# 609          Bukiriro
# 2043             Huzi
# 241        Kirwa Keni
# 1998            Nkome
# 1367      Monduli Juu
# 854          Itunundu
# 1999          Bunduki
# 1830        Kisangasa
# 1904        Ihanamilo
# 698          Nyambiti
# 511            Inyala
# 2030           Pangwi
# 64             Ipinda
# 379             Shume
# 980         Kahangara
# 2027          Chisano
# 746            Ukwama
# 961          Bulongwa
# 1410          Igalala
# dtype: object
#
#
# Unique values from population, limited to 30
#
# 16       35
# 233    2800
# 520     206
# 655     584
# 345     595
# 442     653
# 711     187
# 186      48
# 751    1010
# 378     866
# 526     482
# 287      42
# 43      850
# 172       5
# 231      27
# 246     356
# 405     565
# 663     339
# 994     574
# 835    5016
# 53     1200
# 479     868
# 214     217
# 787     116
# 701     930
# 81      856
# 228     763
# 623      91
# 469     457
# 382    2100
# dtype: int64
#
#
# Unique values from public_meeting, limited to 30
#
# 2      NaN
# 0    False
# 1     True
# dtype: object
#
#
# Unique values from recorded_by, limited to 30
#
# 0    GeoData Consultants Ltd
# dtype: object
#
#
# Unique values from scheme_management, limited to 30
#
# 3                  WUG
# 11               Trust
# 8                  SWC
# 1                  VWC
# 10               Other
# 6     Private operator
# 9              Company
# 5                  WUA
# 2                  NaN
# 12                None
# 0      Water authority
# 4          Water Board
# 7           Parastatal
# dtype: object
#
#
# Unique values from scheme_name, limited to 30
#
# 681                      Mradi wa maji wa tabora mjini
# 1647                        Oljoro Namba 5 pipe scheme
# 1408                             Digodigo water scheme
# 2513                                             Mpute
# 1386             Busunzu /Nyankwi gravity water supply
# 137                                                  N
# 1651                               Marera water supply
# 1703                              Kiyanga water supply
# 1142                                          FinWater
# 1761                                            Kimani
# 1990                                    Tank fu Mwenge
# 2283                                           Muhembe
# 2092                        Ikuna gravity water Scheme
# 4                                 Kigongoi gravity wat
# 1738                               Kifaru Water Supply
# 307                            Kifumangao Water supply
# 2392                        Police Sanya Juu service l
# 1971                                              Ilew
# 347                               Handeni Trunk Main(H
# 1688                                      BL Kiboshoni
# 597                                             Kitowo
# 2017                                     Mkongoro  Two
# 410                                           Msolwa U
# 149                               Water Sector Develop
# 305     KARUKEKERE WATER ENVIRONMENT SANITATION SCHEME
# 2205                                              Iyan
# 2580                                             LANCH
# 1331                               Mamire water Supply
# 820                Seela Sing'isi gravity water supply
# 1308                                            Ifunda
# dtype: object
#
#
# Unique values from permit, limited to 30
#
# 2      NaN
# 0     True
# 1    False
# dtype: object
#
#
# Unique values from construction_year, limited to 30
#
# 35    2002
# 36    1967
# 30    1968
# 18    1986
# 14    1972
# 51    1969
# 6     1992
# 0        0
# 4     2000
# 2     1991
# 17    2010
# 29    2009
# 23    2012
# 32    1994
# 34    1975
# 11    1993
# 15    1999
# 28    1963
# 3     2007
# 48    1971
# 31    1974
# 12    1984
# 24    1982
# 10    2006
# 16    1995
# 54    1966
# 25    1983
# 5     1980
# 38    2004
# 33    2011
# dtype: int64
#
#
# Unique values from extraction_type, limited to 30
# 11            other - rope pump
# 15                       climax
# 13                         cemo
# 7                          mono
# 1                   submersible
# 4                   nira/tanira
# 10               other - swn 81
# 8                 india mark ii
# 9                        swn 80
# 14                       walimi
# 17    other - mkulima/shinyanga
# 5                       afridev
# 6                      windmill
# 16            other - play pump
# 0                           ksb
# 3                       gravity
# 2                         other
# 12               india mark iii
# dtype: object
#
#
# Unique values from extraction_type_group, limited to 30
#
# 3         nira/tanira
# 4             afridev
# 8              swn 80
# 5        wind-powered
# 2             gravity
# 1               other
# 12    other motorpump
# 10          rope pump
# 9      other handpump
# 6                mono
# 0         submersible
# 7       india mark ii
# 11     india mark iii
# dtype: object
#
#
# Unique values from extraction_type_class, limited to 30
#
# 6       rope pump
# 1           other
# 2         gravity
# 5       motorpump
# 0     submersible
# 4    wind-powered
# 3        handpump
# dtype: object
#
#
# Unique values from management, limited to 30
#
# 9              unknown
# 10               other
# 11               trust
# 2                  wug
# 4     private operator
# 1                  vwc
# 3          water board
# 8                  wua
# 5           parastatal
# 0      water authority
# 7              company
# 6       other - school
# dtype: object
#
#
# Unique values from management_group, limited to 30
#
# 2    parastatal
# 1    user-group
# 4       unknown
# 0    commercial
# 3         other
# dtype: object
#
#
# Unique values from payment, limited to 30
#
# 3    pay when scheme fails
# 1                never pay
# 0           pay per bucket
# 4             pay annually
# 6                    other
# 2                  unknown
# 5              pay monthly
# dtype: object
#
#
# Unique values from payment_type, limited to 30
#
# 6         other
# 4      annually
# 1     never pay
# 0    per bucket
# 3    on failure
# 5       monthly
# 2       unknown
# dtype: object
#
#
# Unique values from water_quality, limited to 30
#
# 5                 milky
# 0              coloured
# 1                 salty
# 4       salty abandoned
# 3               unknown
# 2                  soft
# 7    fluoride abandoned
# 6              fluoride
# dtype: object
#
#
# Unique values from quality_group, limited to 30
#
# 2        good
# 5    fluoride
# 0     colored
# 1       salty
# 3     unknown
# 4       milky
# dtype: object
#
#
# Unique values from quantity, limited to 30
#
# 4        seasonal
# 2             dry
# 3         unknown
# 0    insufficient
# 1          enough
# dtype: object
#
#
# Unique values from quantity_group, limited to 30
#
# 0    insufficient
# 1          enough
# 3         unknown
# 4        seasonal
# 2             dry
# dtype: object
#
#
# Unique values from source, limited to 30
#
# 0                     dam
# 7    rainwater harvesting
# 1             machine dbh
# 9                 unknown
# 8                hand dtw
# 4                   other
# 5                    lake
# 6                  spring
# 2            shallow well
# 3                   river
# dtype: object
#
#
# Unique values from source_type, limited to 30
#
# 3              river/lake
# 0                     dam
# 6    rainwater harvesting
# 5                  spring
# 2            shallow well
# 1                borehole
# 4                   other
# dtype: object
#
#
# Unique values from source_class, limited to 30
#
# 2        unknown
# 1    groundwater
# 0        surface
# dtype: object
#
#
# Unique values from waterpoint_type, limited to 30
#
# 3             communal standpipe
# 4                      hand pump
# 6                  cattle trough
# 1    communal standpipe multiple
# 5                improved spring
# 0                            dam
# 2                          other
# dtype: object
#
#
# Unique values from waterpoint_type_group, limited to 30
#
# 0                   dam
# 3             hand pump
# 4       improved spring
# 1    communal standpipe
# 5         cattle trough
# 2                 other
# dtype: object

# %% [markdown]
# We can see that there is one entry of 0 in the column construction_year.

# %%
X_train[X_train.construction_year == 0].shape
# Out:
# (18575, 40)

# %%
X_train.columns.tolist()
# Out:
# ['id',
#  'amount_tsh',
#  'date_recorded',
#  'funder',
#  'gps_height',
#  'installer',
#  'longitude',
#  'latitude',
#  'wpt_name',
#  'num_private',
#  'basin',
#  'subvillage',
#  'region',
#  'region_code',
#  'district_code',
#  'lga',
#  'ward',
#  'population',
#  'public_meeting',
#  'recorded_by',
#  'scheme_management',
#  'scheme_name',
#  'permit',
#  'construction_year',
#  'extraction_type',
#  'extraction_type_group',
#  'extraction_type_class',
#  'management',
#  'management_group',
#  'payment',
#  'payment_type',
#  'water_quality',
#  'quality_group',
#  'quantity',
#  'quantity_group',
#  'source',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'waterpoint_type_group']

# %%
cols_subset = ['ward',
 'population',
 'public_meeting',
 'recorded_by',
 'scheme_management',
 'scheme_name',
 'permit',
 'construction_year',
 'extraction_type',
 'extraction_type_group',
 'extraction_type_class',
 'management',
 'management_group',
 'payment',
 'payment_type',
 'water_quality']

# %%
X_train[X_train.construction_year == 0][cols_subset].sample(n = 100).head(50)
# Out:
#                       ward  population public_meeting  \
# 7283              Shishiyu           0           True
# 46926         Pandagichiza           0           True
# 1361                 Chibe           0           True
# 25257                Ukune           0           True
# 13789                 Wala           0           True
# 37668               Isanga           0           True
# 23632              Nkwenda           0           True
# 2624                  Badi           0           True
# 31154              Railway         430           True
# 26884                Chona           0            NaN
# 46112             Nambambo        1300           True
# 52216              Runzewe           0           True
# 3106      Utengule Usongwe           0           True
# 27735              Mwabuma           0           True
# 26113                Chela           0            NaN
# 42731               Ihembe           0           True
# 2382                 Mlali           0           True
# 31677             Madibira           0           True
# 4690                 Igale           0           True
# 55203             Kikubiji           0           True
# 29426            Sangabuye           0           True
# 57310               Nkinga           0           True
# 720             Nyakabindi           0            NaN
# 8575                Mbogwe           0           True
# 43789  Milingoti Mashariki           1          False
# 47130               Kinaga           0            NaN
# 4378                Sejeli           0           True
# 58135               Ngulla           0           True
# 42203               Sapiwi           0           True
# 21118             Ushirika           0           True
# 58875               Sigili           0           True
# 54803               Rujewa           0          False
# 26443               Ussoke           0           True
# 20166               Mtumba           0           True
# 6160                Kiwira           0           True
# 53979              Mpuguso           0           True
# 34594          Murusagamba           0           True
# 35120              Handali           0           True
# 58611               Ipinda           0           True
# 45946               Mugoma           0           True
# 8491               Bujashi           0           True
# 57529                Lyoma           0           True
# 58314               Ngwala           0           True
# 55614              Chimala           0           True
# 45933            Chalangwa           0           True
# 30534              Izimbya           0           True
# 23774                Nkoma           0           True
# 7370                Zoissa           0           True
# 11662             Nambinzo           0          False
# 52905              Izimbya           0           True
#
#                    recorded_by scheme_management                  scheme_name  \
# 7283   GeoData Consultants Ltd               WUG                          NaN
# 46926  GeoData Consultants Ltd               WUG                          NaN
# 1361   GeoData Consultants Ltd               WUG                          NaN
# 25257  GeoData Consultants Ltd               NaN                          NaN
# 13789  GeoData Consultants Ltd               VWC                          NaN
# 37668  GeoData Consultants Ltd               WUG                          NaN
# 23632  GeoData Consultants Ltd               VWC            Nkwenda water sup
# 2624   GeoData Consultants Ltd               VWC                          NaN
# 31154  GeoData Consultants Ltd   Water authority                       Kizota
# 26884  GeoData Consultants Ltd               NaN                          NaN
# 46112  GeoData Consultants Ltd               VWC                     Nampemba
# 52216  GeoData Consultants Ltd               WUG                          NaN
# 3106   GeoData Consultants Ltd               VWC                          NaN
# 27735  GeoData Consultants Ltd               WUG                         None
# 26113  GeoData Consultants Ltd               NaN                          NaN
# 42731  GeoData Consultants Ltd               NaN                          NaN
# 2382   GeoData Consultants Ltd               VWC                         Mlal
# 31677  GeoData Consultants Ltd               VWC                          NaN
# 4690   GeoData Consultants Ltd               VWC                          NaN
# 55203  GeoData Consultants Ltd               VWC                          NaN
# 29426  GeoData Consultants Ltd               VWC                          NaN
# 57310  GeoData Consultants Ltd   Water authority                          NaN
# 720    GeoData Consultants Ltd               WUG                          NaN
# 8575   GeoData Consultants Ltd               WUG                          NaN
# 43789  GeoData Consultants Ltd        Parastatal                          NaN
# 47130  GeoData Consultants Ltd               NaN                          NaN
# 4378   GeoData Consultants Ltd               VWC                         Mban
# 58135  GeoData Consultants Ltd               VWC                          NaN
# 42203  GeoData Consultants Ltd               WUG                          NaN
# 21118  GeoData Consultants Ltd               WUG                          NaN
# 58875  GeoData Consultants Ltd               VWC                          NaN
# 54803  GeoData Consultants Ltd       Water Board                          NaN
# 26443  GeoData Consultants Ltd               VWC                          NaN
# 20166  GeoData Consultants Ltd               VWC                         Ihum
# 6160   GeoData Consultants Ltd               VWC                            K
# 53979  GeoData Consultants Ltd               VWC                            K
# 34594  GeoData Consultants Ltd               VWC      Nyamisuli Water project
# 35120  GeoData Consultants Ltd               VWC                         Hand
# 58611  GeoData Consultants Ltd               VWC  ngamanga water supplied sch
# 45946  GeoData Consultants Ltd               VWC       Bubujiko spring source
# 8491   GeoData Consultants Ltd               VWC                          NaN
# 57529  GeoData Consultants Ltd               VWC                          NaN
# 58314  GeoData Consultants Ltd               VWC                          NaN
# 55614  GeoData Consultants Ltd               VWC                          NaN
# 45933  GeoData Consultants Ltd               VWC                          NaN
# 30534  GeoData Consultants Ltd               VWC                          NaN
# 23774  GeoData Consultants Ltd               WUG                         None
# 7370   GeoData Consultants Ltd               VWC                         Chit
# 11662  GeoData Consultants Ltd               VWC                          NaN
# 52905  GeoData Consultants Ltd               VWC                          NaN
#
#       permit  construction_year extraction_type extraction_type_group  \
# 7283   False                  0     nira/tanira           nira/tanira
# 46926   True                  0     nira/tanira           nira/tanira
# 1361   False                  0     nira/tanira           nira/tanira
# 25257   True                  0           other                 other
# 13789   True                  0   india mark ii         india mark ii
# 37668  False                  0     nira/tanira           nira/tanira
# 23632   True                  0         gravity               gravity
# 2624   False                  0           other                 other
# 31154   True                  0     submersible           submersible
# 26884  False                  0     nira/tanira           nira/tanira
# 46112  False                  0     nira/tanira           nira/tanira
# 52216   True                  0     nira/tanira           nira/tanira
# 3106    True                  0         gravity               gravity
# 27735   True                  0     nira/tanira           nira/tanira
# 26113  False                  0     nira/tanira           nira/tanira
# 42731   True                  0     nira/tanira           nira/tanira
# 2382   False                  0         gravity               gravity
# 31677  False                  0         gravity               gravity
# 4690    True                  0         gravity               gravity
# 55203   True                  0         afridev               afridev
# 29426   True                  0     nira/tanira           nira/tanira
# 57310   True                  0     submersible           submersible
# 720    False                  0     nira/tanira           nira/tanira
# 8575    True                  0     nira/tanira           nira/tanira
# 43789  False                  0  other - swn 81        other handpump
# 47130   True                  0           other                 other
# 4378    True                  0     submersible           submersible
# 58135   True                  0         afridev               afridev
# 42203  False                  0     nira/tanira           nira/tanira
# 21118   True                  0     nira/tanira           nira/tanira
# 58875  False                  0   india mark ii         india mark ii
# 54803   True                  0         gravity               gravity
# 26443   True                  0         afridev               afridev
# 20166  False                  0            mono                  mono
# 6160     NaN                  0         gravity               gravity
# 53979    NaN                  0         gravity               gravity
# 34594  False                  0         gravity               gravity
# 35120   True                  0        windmill          wind-powered
# 58611   True                  0         gravity               gravity
# 45946  False                  0         gravity               gravity
# 8491    True                  0           other                 other
# 57529   True                  0           other                 other
# 58314   True                  0         gravity               gravity
# 55614  False                  0          swn 80                swn 80
# 45933   True                  0         gravity               gravity
# 30534   True                  0           other                 other
# 23774   True                  0     nira/tanira           nira/tanira
# 7370   False                  0            mono                  mono
# 11662  False                  0          swn 80                swn 80
# 52905   True                  0          swn 80                swn 80
#
#       extraction_type_class   management management_group  \
# 7283               handpump          wug       user-group
# 46926              handpump          wug       user-group
# 1361               handpump          wug       user-group
# 25257                 other          wug       user-group
# 13789              handpump          vwc       user-group
# 37668              handpump          wug       user-group
# 23632               gravity          vwc       user-group
# 2624                  other          vwc       user-group
# 31154           submersible          wug       user-group
# 26884              handpump          wug       user-group
# 46112              handpump          vwc       user-group
# 52216              handpump          wug       user-group
# 3106                gravity          wug       user-group
# 27735              handpump          wug       user-group
# 26113              handpump      unknown          unknown
# 42731              handpump          vwc       user-group
# 2382                gravity          vwc       user-group
# 31677               gravity          vwc       user-group
# 4690                gravity          wug       user-group
# 55203              handpump          vwc       user-group
# 29426              handpump          vwc       user-group
# 57310           submersible          vwc       user-group
# 720                handpump          wug       user-group
# 8575               handpump          wug       user-group
# 43789              handpump   parastatal       parastatal
# 47130                 other      unknown          unknown
# 4378            submersible          vwc       user-group
# 58135              handpump          vwc       user-group
# 42203              handpump          wug       user-group
# 21118              handpump          wug       user-group
# 58875              handpump          vwc       user-group
# 54803               gravity  water board       user-group
# 26443              handpump          vwc       user-group
# 20166             motorpump          vwc       user-group
# 6160                gravity          vwc       user-group
# 53979               gravity          vwc       user-group
# 34594               gravity          vwc       user-group
# 35120          wind-powered          vwc       user-group
# 58611               gravity          vwc       user-group
# 45946               gravity          vwc       user-group
# 8491                  other          vwc       user-group
# 57529                 other          vwc       user-group
# 58314               gravity          vwc       user-group
# 55614              handpump          vwc       user-group
# 45933               gravity          vwc       user-group
# 30534                 other          vwc       user-group
# 23774              handpump          wug       user-group
# 7370              motorpump          vwc       user-group
# 11662              handpump          vwc       user-group
# 52905              handpump          vwc       user-group
#
#                      payment payment_type water_quality
# 7283               never pay    never pay          soft
# 46926              never pay    never pay          soft
# 1361          pay per bucket   per bucket         salty
# 25257                unknown      unknown         milky
# 13789              never pay    never pay          soft
# 37668                  other        other          soft
# 23632              never pay    never pay          soft
# 2624               never pay    never pay          soft
# 31154         pay per bucket   per bucket          soft
# 26884                unknown      unknown         milky
# 46112         pay per bucket   per bucket         salty
# 52216                unknown      unknown          soft
# 3106   pay when scheme fails   on failure          soft
# 27735              never pay    never pay          soft
# 26113                unknown      unknown       unknown
# 42731              never pay    never pay          soft
# 2382               never pay    never pay          soft
# 31677           pay annually     annually          soft
# 4690   pay when scheme fails   on failure          soft
# 55203           pay annually     annually          soft
# 29426              never pay    never pay          soft
# 57310         pay per bucket   per bucket         salty
# 720                  unknown      unknown          soft
# 8575                 unknown      unknown          soft
# 43789              never pay    never pay          soft
# 47130                unknown      unknown       unknown
# 4378          pay per bucket   per bucket         salty
# 58135              never pay    never pay          soft
# 42203              never pay    never pay          soft
# 21118                unknown      unknown          soft
# 58875            pay monthly      monthly         salty
# 54803              never pay    never pay      coloured
# 26443              never pay    never pay         salty
# 20166            pay monthly      monthly         salty
# 6160               never pay    never pay          soft
# 53979              never pay    never pay          soft
# 34594            pay monthly      monthly          soft
# 35120              never pay    never pay          soft
# 58611            pay monthly      monthly          soft
# 45946              never pay    never pay          soft
# 8491               never pay    never pay          soft
# 57529              never pay    never pay          soft
# 58314              never pay    never pay          soft
# 55614            pay monthly      monthly      fluoride
# 45933            pay monthly      monthly          soft
# 30534              never pay    never pay          soft
# 23774              never pay    never pay          soft
# 7370          pay per bucket   per bucket         salty
# 11662              never pay    never pay          soft
# 52905              never pay    never pay          soft

# %%
def count_values(df, value):
    """
    Returns a pandas DataFrame with the names of the original features in the index and the number of
    occurrences of the value as the values of the first column and the same as the percentage of all
    observations in the second column.

    If the passed value is boolean, compares with boolean values in the DataFrame. If the passed value
    is a string, compares with object (string) values in the DataFrame. Otherwise, only compares with
    values of the same data type.

    Parameters:
    -----------
    df: pandas DataFrame.

    value : str / int / float / bool.
        The value to be counted.

    Returns:
    --------
    pandas DataFrame.
    """

    if isinstance(value, bool):
        value_mask = df.apply(lambda x: isinstance(x[0], bool), axis=0)
    elif isinstance(value, str):
        value_mask = df.dtypes == 'object'
    elif isinstance(value, int):
        value_mask = df.dtypes == 'int64'
    elif isinstance(value, float):
        value_mask = df.dtypes == 'float64'
    else:
        raise TypeError("Input value must be of type bool, str, int, or float.")

    count_series = df.loc[:, value_mask].eq(value).sum().sort_values(ascending=False)
    percent_series = count_series / len(df) * 100
    percent_series = percent_series.round(1)

    data = {
        f"Count of {value}": count_series,
        f"{value}'s as % of Total": percent_series
    }
    result_df = pd.DataFrame(data)
    result_df.index.name = 'Feature'
    result_df.sort_values(by=f"Count of {value}", ascending=False, inplace=True)

    return result_df[result_df['Count of {}'.format(value)] > 0]

# %%
X_train[['permit', 'scheme_management']]
# Out:
#       permit scheme_management
# 44928   True   Water authority
# 31178   True               VWC
# 9485    True               NaN
# 955     True               WUG
# 29186   True       Water Board
# ...      ...               ...
# 54343   True       Water Board
# 38158  False               VWC
# 860    False  Private operator
# 15795   True               WUG
# 56422   True           Company
#
# [53460 rows x 2 columns]

# %% [markdown]
# <center>Examining potentially not obvious missing values</center>

# %%
count_values(df = X_train, value = 0)
# Out:
#                    Count of 0  0's as % of Total
# Feature
# num_private             52778               98.7
# population              19189               35.9
# construction_year       18575               34.7
# gps_height              18313               34.3
# district_code              22                0.0
# id                          1                0.0

# %%
X_train.num_private.value_counts(normalize = True).round(3).head(3)
# Out:
# 0    0.987
# 6    0.001
# 1    0.001
# Name: num_private, dtype: float64

# %%
X_train[X_train.num_private == 0].sample(n = 10)
# Out:
#           id  amount_tsh date_recorded                   funder  gps_height  \
# 58020  63464         0.0    2012-10-19                   Hesawa        1446
# 4742   39039      5000.0    2013-03-03                    Cafod        1150
# 9716   45464         0.0    2013-03-16  Lawatefuka Water Supply        1726
# 29026  24821         0.0    2011-08-02   Government Of Tanzania           0
# 44329  13305       500.0    2011-02-22                   Danida        1671
# 36952  39321         0.0    2011-04-01                      NaN           0
# 58293  72573         0.0    2011-04-22                      NaN           0
# 42463  14762        10.0    2013-03-20       Private Individual        1785
# 22680  36434       500.0    2011-03-21                  Caritas         321
# 35023   2822         0.0    2011-08-07   Government Of Tanzania           0
#
#                   installer  longitude  latitude                 wpt_name  \
# 58020                Hesawa  34.408651 -1.325539                 Kebageni
# 4742                  CBHCC  36.937861 -3.364489  Surumala Primary School
# 9716   Lawatefuka water sup  37.122769 -3.139010       Kwa Vaileth P Urio
# 29026            Government  33.389842 -2.619058                 Kwa Zaka
# 44329                 Danid  34.494507 -9.836757                     none
# 36952                   NaN  33.270768 -9.488684               Kwa Luinga
# 58293                   NaN  33.737222 -9.191026           Kwa Mwabuponde
# 42463                  Dmdd  35.841652 -3.238924                    Barai
# 22680                   DWE  36.408757 -8.654554                Kwa Milao
# 35023                GOVERN  32.964478 -2.880652                  Sosaiti
#
#        num_private          basin  subvillage       region  region_code  \
# 58020            0  Lake Victoria  Nyametembe         Mara           20
# 4742             0        Pangani    Surumala       Arusha            2
# 9716             0        Pangani       Maini  Kilimanjaro            3
# 29026            0  Lake Victoria     Mizwale       Mwanza           19
# 44329            0     Lake Nyasa    Ngengeja       Iringa           11
# 36952            0     Lake Nyasa   Sekondari        Mbeya           12
# 58293            0     Lake Nyasa      Masebe        Mbeya           12
# 42463            0       Internal       Njoro       Arusha           24
# 22680            0         Rufiji    Mlindila     Morogoro            5
# 35023            0  Lake Victoria     Sumbugu       Mwanza           19
#
#        district_code        lga            ward  population public_meeting  \
# 58020              1     Tarime           Turwa          50           True
# 4742               7       Meru        Kikatiti         500           True
# 9716               7       Siha  Siha Kaskazini           1           True
# 29026              2       Magu         Nyigogo           0           True
# 44329              5     Ludewa         Mawengi          59           True
# 36952              5      Ileje          Bupigu           0           True
# 58293              4     Rungwe            Suma           0           True
# 42463             30     Karatu      Mbulumbulu         125           True
# 22680              4     Ulanga           Itete         259           True
# 35023              7  Missungwi         Sumbugu           0            NaN
#
#                    recorded_by scheme_management  \
# 58020  GeoData Consultants Ltd               NaN
# 4742   GeoData Consultants Ltd       Water Board
# 9716   GeoData Consultants Ltd       Water Board
# 29026  GeoData Consultants Ltd               VWC
# 44329  GeoData Consultants Ltd               VWC
# 36952  GeoData Consultants Ltd               VWC
# 58293  GeoData Consultants Ltd               VWC
# 42463  GeoData Consultants Ltd               VWC
# 22680  GeoData Consultants Ltd       Water Board
# 35023  GeoData Consultants Ltd               VWC
#
#                          scheme_name permit  construction_year  \
# 58020                            NaN   True               1998
# 4742   Kimasaki gravity water supply   True               2003
# 9716                        BL Losei   True               2008
# 29026                            NaN   True                  0
# 44329                         Makanj  False               1992
# 36952                            NaN  False                  0
# 58293                              S    NaN                  0
# 42463      Jumuhiya ya watumia  maji   True               2009
# 22680                       Itete wa   True               2006
# 35023                            NaN   True                  0
#
#       extraction_type extraction_type_group extraction_type_class  \
# 58020           other                 other                 other
# 4742          gravity               gravity               gravity
# 9716          gravity               gravity               gravity
# 29026            mono                  mono             motorpump
# 44329         gravity               gravity               gravity
# 36952         gravity               gravity               gravity
# 58293         gravity               gravity               gravity
# 42463         gravity               gravity               gravity
# 22680         gravity               gravity               gravity
# 35023             ksb           submersible           submersible
#
#         management management_group         payment payment_type  \
# 58020          vwc       user-group         unknown      unknown
# 4742           wua       user-group  pay per bucket   per bucket
# 9716   water board       user-group     pay monthly      monthly
# 29026          vwc       user-group  pay per bucket   per bucket
# 44329          vwc       user-group    pay annually     annually
# 36952          vwc       user-group         unknown      unknown
# 58293          vwc       user-group         unknown      unknown
# 42463          vwc       user-group  pay per bucket   per bucket
# 22680          wug       user-group     pay monthly      monthly
# 35023          vwc       user-group       never pay    never pay
#
#       water_quality quality_group      quantity quantity_group        source  \
# 58020          soft          good        enough         enough  shallow well
# 4742           soft          good  insufficient   insufficient         river
# 9716           soft          good        enough         enough        spring
# 29026          soft          good        enough         enough   machine dbh
# 44329          soft          good        enough         enough        spring
# 36952          soft          good  insufficient   insufficient        spring
# 58293          soft          good        enough         enough         river
# 42463          soft          good      seasonal       seasonal         river
# 22680          soft          good        enough         enough         river
# 35023          soft          good        enough         enough          lake
#
#         source_type source_class              waterpoint_type  \
# 58020  shallow well  groundwater                        other
# 4742     river/lake      surface  communal standpipe multiple
# 9716         spring  groundwater           communal standpipe
# 29026      borehole  groundwater  communal standpipe multiple
# 44329        spring  groundwater           communal standpipe
# 36952        spring  groundwater           communal standpipe
# 58293    river/lake      surface           communal standpipe
# 42463    river/lake      surface           communal standpipe
# 22680    river/lake      surface           communal standpipe
# 35023    river/lake      surface  communal standpipe multiple
#
#       waterpoint_type_group
# 58020                 other
# 4742     communal standpipe
# 9716     communal standpipe
# 29026    communal standpipe
# 44329    communal standpipe
# 36952    communal standpipe
# 58293    communal standpipe
# 42463    communal standpipe
# 22680    communal standpipe
# 35023    communal standpipe

# %% [markdown]
# Regardless whether num_private, for which description is not available, can really be 0 or it is a missing value, we can safely remove it, because the feature which has the same value in 99 % of cases wouldn't be very useful anyway. There is a big chance that t is a missing value, too.

# %%
del X_train['num_private']

# %%
X_train.head(2)
# Out:
#           id  amount_tsh date_recorded funder  gps_height installer  \
# 44928  31080         0.0    2012-10-10    Dwe           0    WEDECO
# 31178  17282        50.0    2013-02-16  Jaica         -33     Tasaf
#
#        longitude   latitude           wpt_name                    basin  \
# 44928  33.179596  -4.214966          Hospitali                 Internal
# 31178  40.322805 -10.456297  Kwa Bakari Ismail  Ruvuma / Southern Coast
#
#       subvillage  region  region_code  district_code           lga  \
# 44928    Majengo  Tabora           14              1         Nzega
# 31178    Kipingo  Mtwara           99              1  Mtwara Rural
#
#               ward  population public_meeting              recorded_by  \
# 44928  Nzega Urban           0          False  GeoData Consultants Ltd
# 31178    Mahurunga        1000           True  GeoData Consultants Ltd
#
#       scheme_management            scheme_name permit  construction_year  \
# 44928   Water authority  Kilimi and uchama dam   True                  0
# 31178               VWC   Tangazo water supply   True               2008
#
#       extraction_type extraction_type_group extraction_type_class  \
# 44928             ksb           submersible           submersible
# 31178     submersible           submersible           submersible
#
#             management management_group         payment payment_type  \
# 44928  water authority       commercial  pay per bucket   per bucket
# 31178              vwc       user-group  pay per bucket   per bucket
#
#       water_quality quality_group      quantity quantity_group       source  \
# 44928      coloured       colored  insufficient   insufficient          dam
# 31178         salty         salty        enough         enough  machine dbh
#
#       source_type source_class              waterpoint_type  \
# 44928         dam      surface                          dam
# 31178    borehole  groundwater  communal standpipe multiple
#
#       waterpoint_type_group
# 44928                   dam
# 31178    communal standpipe

# %%
count_values(df = X_train, value = '-')
# Out:
#            Count of -  -'s as % of Total
# Feature
# installer           3                0.0

# %%
X_train[X_train.installer == '-']
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 10217  42616         0.0    2011-08-03         Kalebejo Parish           0
# 25769  21336         0.0    2011-07-26  Government Of Tanzania           0
# 20968  10873         0.0    2011-07-26  Government Of Tanzania           0
#
#       installer  longitude  latitude         wpt_name          basin  \
# 10217         -  32.356645 -2.499427  Kalebejo Parish  Lake Victoria
# 25769         -  32.674665 -2.506721    Health Center  Lake Victoria
# 20968         -  32.677150 -2.508912     Kwa Madebele  Lake Victoria
#
#              subvillage  region  region_code  district_code        lga  \
# 10217        Nyang'Ombe  Mwanza           19              5  Sengerema
# 25769  Katungulu Center  Mwanza           19              5  Sengerema
# 20968  Katungulu Center  Mwanza           19              5  Sengerema
#
#             ward  population public_meeting              recorded_by  \
# 10217   Kalebezo           0            NaN  GeoData Consultants Ltd
# 25769  Katunguru           0           True  GeoData Consultants Ltd
# 20968  Katunguru           0           True  GeoData Consultants Ltd
#
#       scheme_management                scheme_name permit  construction_year  \
# 10217  Private operator                       None   True                  0
# 25769               VWC  water supply in katungulu   True                  0
# 20968               VWC     water supply Katungulu   True                  0
#
#       extraction_type extraction_type_group extraction_type_class  \
# 10217          swn 80                swn 80              handpump
# 25769           other                 other                 other
# 20968           other                 other                 other
#
#              management management_group         payment payment_type  \
# 10217  private operator       commercial       never pay    never pay
# 25769               vwc       user-group  pay per bucket   per bucket
# 20968               vwc       user-group  pay per bucket   per bucket
#
#          water_quality quality_group      quantity quantity_group  \
# 10217  salty abandoned         salty  insufficient   insufficient
# 25769             soft          good        enough         enough
# 20968             soft          good        enough         enough
#
#              source   source_type source_class     waterpoint_type  \
# 10217  shallow well  shallow well  groundwater           hand pump
# 25769          lake    river/lake      surface  communal standpipe
# 20968          lake    river/lake      surface  communal standpipe
#
#       waterpoint_type_group
# 10217             hand pump
# 25769    communal standpipe
# 20968    communal standpipe

# %% [markdown]
# hyphens ('-') must represent NaNs.

# %%
X_train.loc[X_train.installer == '-' , 'installer'] = np.nan

# %%
X_train[X_train.installer == '-']
# Out:
# Empty DataFrame
# Columns: [id, amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group]
# Index: []

# %%
X_train.shape
# Out:
# (53460, 39)

# %%
X_train[X_train.population == 0]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 44928  31080         0.0    2012-10-10                     Dwe           0
# 955    44490         0.0    2012-10-12                   Rwssp           0
# 11376  12282         0.0    2011-08-07  Government Of Tanzania           0
# 41084   4136         0.0    2011-03-30                     NaN           0
# 13035  57121         0.0    2011-08-27                  Hesawa           0
# ...      ...         ...           ...                     ...         ...
# 41090  50530         0.0    2011-03-24              World Bank           0
# 44131   5457         0.0    2011-03-14                     Bsf           0
# 37194  73111         0.0    2011-02-26                    Kkkt        1922
# 6265   47858         0.0    2011-03-10                     Bsf           0
# 15795  49444         0.0    2012-10-31                   Rwssp           0
#
#         installer  longitude      latitude         wpt_name          basin  \
# 44928      WEDECO  33.179596 -4.214966e+00        Hospitali       Internal
# 955         RWSSP  33.071249 -3.803178e+00           Ujamaa  Lake Victoria
# 11376  Government   0.000000 -2.000000e-08          Bombani  Lake Victoria
# 41084         NaN  33.037957 -9.365355e+00       Tingatinga     Lake Nyasa
# 13035         DWE  33.572619 -2.694380e+00    Kwashilangila  Lake Victoria
# ...           ...        ...           ...              ...            ...
# 41090       Inter  36.644403 -6.249858e+00  Kwa John Makago    Wami / Ruvu
# 44131         DWE  35.238399 -5.172737e+00        Machineni       Internal
# 37194       Commu  34.230959 -9.369277e+00             none     Lake Nyasa
# 6265         Gove  35.547568 -6.336433e+00           Mnadan       Internal
# 15795      WEDECO  34.316586 -3.107161e+00         Muungano  Lake Victoria
#
#       subvillage     region  region_code  district_code              lga  \
# 44928    Majengo     Tabora           14              1            Nzega
# 955       Busubi  Shinyanga           17              3  Shinyanga Rural
# 11376   K/Center     Mwanza           19              6            Geita
# 41084      Ibana      Mbeya           12              5            Ileje
# 13035     Makala     Mwanza           19              2           Kwimba
# ...          ...        ...          ...            ...              ...
# 41090        NaN     Dodoma            1              3           Kongwa
# 44131  Kilimba B     Dodoma            1              1           Kondoa
# 37194  Ikonda Bo     Iringa           11              3           Makete
# 6265      Kikuyu     Dodoma            1              6             Bahi
# 15795     Ijosho  Shinyanga           17              6            Meatu
#
#               ward  population public_meeting              recorded_by  \
# 44928  Nzega Urban           0          False  GeoData Consultants Ltd
# 955          Didia           0           True  GeoData Consultants Ltd
# 11376       Kakora           0           True  GeoData Consultants Ltd
# 41084      Chitete           0           True  GeoData Consultants Ltd
# 13035        Iseni           0           True  GeoData Consultants Ltd
# ...            ...         ...            ...                      ...
# 41090         Iduo           0           True  GeoData Consultants Ltd
# 44131        Ovada           0           True  GeoData Consultants Ltd
# 37194     Lupalilo           0           True  GeoData Consultants Ltd
# 6265       Ibugule           0           True  GeoData Consultants Ltd
# 15795     Sakasaka           0           True  GeoData Consultants Ltd
#
#       scheme_management            scheme_name permit  construction_year  \
# 44928   Water authority  Kilimi and uchama dam   True                  0
# 955                 WUG                    NaN   True                  0
# 11376               VWC             Nyamtukuza   True                  0
# 41084               VWC                    NaN  False                  0
# 13035               NaN                    NaN   True                  0
# ...                 ...                    ...    ...                ...
# 41090               VWC                   Iduo  False                  0
# 44131               VWC                   Ovad  False                  0
# 37194               VWC                 Ikonda  False               2000
# 6265                VWC                   Nkho   True                  0
# 15795               WUG                   None   True                  0
#
#       extraction_type extraction_type_group extraction_type_class  \
# 44928             ksb           submersible           submersible
# 955             other                 other                 other
# 11376             ksb           submersible           submersible
# 41084     nira/tanira           nira/tanira              handpump
# 13035     nira/tanira           nira/tanira              handpump
# ...               ...                   ...                   ...
# 41090     submersible           submersible           submersible
# 44131            cemo       other motorpump             motorpump
# 37194         gravity               gravity               gravity
# 6265             mono                  mono             motorpump
# 15795     nira/tanira           nira/tanira              handpump
#
#             management management_group         payment payment_type  \
# 44928  water authority       commercial  pay per bucket   per bucket
# 955                wug       user-group       never pay    never pay
# 11376              vwc       user-group         unknown      unknown
# 41084              vwc       user-group         unknown      unknown
# 13035              vwc       user-group       never pay    never pay
# ...                ...              ...             ...          ...
# 41090              vwc       user-group  pay per bucket   per bucket
# 44131              vwc       user-group  pay per bucket   per bucket
# 37194              vwc       user-group       never pay    never pay
# 6265               vwc       user-group  pay per bucket   per bucket
# 15795              wug       user-group       never pay    never pay
#
#       water_quality quality_group      quantity quantity_group        source  \
# 44928      coloured       colored  insufficient   insufficient           dam
# 955            soft          good        enough         enough  shallow well
# 11376       unknown       unknown           dry            dry          lake
# 41084          soft          good  insufficient   insufficient  shallow well
# 13035          soft          good        enough         enough  shallow well
# ...             ...           ...           ...            ...           ...
# 41090         salty         salty           dry            dry   machine dbh
# 44131          soft          good        enough         enough   machine dbh
# 37194          soft          good        enough         enough        spring
# 6265           soft          good        enough         enough   machine dbh
# 15795          soft          good        enough         enough  shallow well
#
#         source_type source_class              waterpoint_type  \
# 44928           dam      surface                          dam
# 955    shallow well  groundwater                        other
# 11376    river/lake      surface                    hand pump
# 41084  shallow well  groundwater                    hand pump
# 13035  shallow well  groundwater                    hand pump
# ...             ...          ...                          ...
# 41090      borehole  groundwater  communal standpipe multiple
# 44131      borehole  groundwater           communal standpipe
# 37194        spring  groundwater           communal standpipe
# 6265       borehole  groundwater           communal standpipe
# 15795  shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# 44928                   dam
# 955                   other
# 11376             hand pump
# 41084             hand pump
# 13035             hand pump
# ...                     ...
# 41090    communal standpipe
# 44131    communal standpipe
# 37194    communal standpipe
# 6265     communal standpipe
# 15795             hand pump
#
# [19189 rows x 39 columns]

# %%
X_train.loc[ : , 'exact_location'] = [(long, lat) for long, lat in zip(X_train.longitude, X_train.latitude)]
# Out:
# /tmp/ipykernel_164/888980537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.loc[ : , 'exact_location'] = [(long, lat) for long, lat in zip(X_train.longitude, X_train.latitude)]

# %%
X_train.sample(n = 1000).groupby('exact_location')['population'].unique()
# Out:
# exact_location
# (0.0, -2e-08)                          [0]
# (29.679249100000003, -4.75710463)    [300]
# (29.686622, -4.85012752)             [355]
# (29.6878412, -4.75124221)            [100]
# (29.69940089, -4.92150741)             [0]
#                                      ...
# (39.87912886, -10.80052368)            [1]
# (40.03365787, -10.63815136)          [183]
# (40.12256838, -10.57438628)          [400]
# (40.15590812, -10.26776804)          [210]
# (40.30121406, -10.50351101)          [300]
# Name: population, Length: 970, dtype: object

# %%
(X_train.sample(n = 1000).groupby('exact_location')['population'].nunique() == 1).all()
# Out:
# True

# %% [markdown]
# Out of 1000 random locations, each location with the same coordinates had the same population, which mean that there are no apparent isses whith the quality of population data.

# %%
del X_train['exact_location']

# %%
X_train.sample(n = 1000).groupby('subvillage')['population'].unique().head(60)
# Out:
# subvillage
# Amani                         [680, 625]
# Amrushu Mamba                        [1]
# Azimio                               [0]
# Barabara 7                         [172]
# Barabarani                           [1]
# Barabarani A                         [0]
# Barabaranyoka                      [100]
# Baranyota                           [50]
# Beach                                [1]
# Betherehemu                         [60]
# Bigabilo A                        [1200]
# Biharule                           [350]
# Bitale B                           [630]
# Biyungu                              [0]
# Bomalang'Ombe                       [96]
# Bomani                       [2000, 600]
# Bombani                              [0]
# Bomo                                 [1]
# Bomu                                [20]
# Bondeni                            [630]
# Bubata                               [0]
# Buhinda                              [0]
# Bujingwa                             [0]
# Bulibata                             [0]
# Bulifani                             [0]
# Bulunde                              [0]
# Bunamhala B                          [0]
# Bunigonzi No 3                       [0]
# Bunogwz                              [0]
# Bunzumani                            [0]
# Bupamba                              [0]
# Busagara                           [370]
# Busolwa Kona                         [0]
# Busungu                              [0]
# Butiama                            [610]
# Butulumba                            [0]
# Bwawan                               [0]
# Bwawani                            [100]
# Bwawani B                            [0]
# Cca                                 [80]
# Ccm                                  [0]
# Center             [250, 2000, 91, 2250]
# Central B                          [350]
# Centre                         [30, 500]
# Chabda                             [216]
# Chakwale Mjini                      [80]
# Chalinze Mzee A                     [40]
# Chalinze Mzee B                     [20]
# Chamakera                           [30]
# Chamani                              [1]
# Chambogo                           [250]
# Champera                             [0]
# Chamuyaga B                        [350]
# Chang'Mbe                          [830]
# Chanyamilima                         [0]
# Chanzuru Kati                      [545]
# Chauganga                          [200]
# Chaya                                [0]
# Chela Center                         [0]
# Cheleweni B                        [345]
# Name: population, dtype: object

# %% [markdown]
# Population refers to population around the well, so we might have multiple values of population in a ward or even in subvillage. Browsing for sample villages with zero poplation in the Web we find that in fact they do have a population, which makes sense, since there is little incentive to build a well for some lone wanderers in uninhabited places..

# %%
X_train.loc[X_train.population == 0, 'population'] = np.nan

# %%
X_train.population.isnull().sum()
# Out:
# 19189

# %%
X_train.head(2)
# Out:
#           id  amount_tsh date_recorded funder  gps_height installer  \
# 44928  31080         0.0    2012-10-10    Dwe           0    WEDECO
# 31178  17282        50.0    2013-02-16  Jaica         -33     Tasaf
#
#        longitude   latitude           wpt_name                    basin  \
# 44928  33.179596  -4.214966          Hospitali                 Internal
# 31178  40.322805 -10.456297  Kwa Bakari Ismail  Ruvuma / Southern Coast
#
#       subvillage  region  region_code  district_code           lga  \
# 44928    Majengo  Tabora           14              1         Nzega
# 31178    Kipingo  Mtwara           99              1  Mtwara Rural
#
#               ward  population public_meeting              recorded_by  \
# 44928  Nzega Urban         NaN          False  GeoData Consultants Ltd
# 31178    Mahurunga      1000.0           True  GeoData Consultants Ltd
#
#       scheme_management            scheme_name permit  construction_year  \
# 44928   Water authority  Kilimi and uchama dam   True                  0
# 31178               VWC   Tangazo water supply   True               2008
#
#       extraction_type extraction_type_group extraction_type_class  \
# 44928             ksb           submersible           submersible
# 31178     submersible           submersible           submersible
#
#             management management_group         payment payment_type  \
# 44928  water authority       commercial  pay per bucket   per bucket
# 31178              vwc       user-group  pay per bucket   per bucket
#
#       water_quality quality_group      quantity quantity_group       source  \
# 44928      coloured       colored  insufficient   insufficient          dam
# 31178         salty         salty        enough         enough  machine dbh
#
#       source_type source_class              waterpoint_type  \
# 44928         dam      surface                          dam
# 31178    borehole  groundwater  communal standpipe multiple
#
#       waterpoint_type_group
# 44928                   dam
# 31178    communal standpipe

# %%
(X_train.isnull().sum().sort_values(ascending = False) / len(X_train)).round(2).head(10)
# Out:
# scheme_name              0.47
# population               0.36
# scheme_management        0.06
# installer                0.06
# funder                   0.06
# public_meeting           0.06
# permit                   0.05
# subvillage               0.01
# payment_type             0.00
# extraction_type_class    0.00
# dtype: float64

# %%
count_values(df = X_train, value = 0)
# Out:
#                    Count of 0  0's as % of Total
# Feature
# construction_year       18575               34.7
# gps_height              18313               34.3
# district_code              22                0.0
# id                          1                0.0

# %%
X_train.construction_year.describe().round(2)
# Out:
# count    53460.00
# mean      1303.02
# std        950.88
# min          0.00
# 25%          0.00
# 50%       1986.00
# 75%       2004.00
# max       2013.00
# Name: construction_year, dtype: float64

# %% [markdown]
# We can see that the 0 entries skew the mean value of the construction_year downwards, so that the average construction year is 1300, which is not a very probable value.

# %%
X_train.construction_year.plot.hist(figsize = (8, 4.5))
plt.title('The distribution of the construction year, including zero entries')
plt.xlabel('Year')
plt.show()

# %%
X_train[X_train.construction_year != 0].construction_year.plot.hist(figsize = (8, 4.5))
plt.title('The distribution of the construction year, excluding zero entries')
plt.xlabel('Year')
plt.grid()
plt.show()

# %%
ecdf = ECDF(X_train[X_train.construction_year != 0].construction_year)

# %%
plt.figure(figsize = (9, 6))
plt.step(ecdf.x, ecdf.y)
plt.grid()
plt.yticks([i / 10 for i in range(11)])
plt.xticks([*range(1960, 2020, 5)])
plt.title('Fractions of obervations with year less than given year across the years (ECDF) ')
plt.ylabel('Fraction of years less than given year')
plt.show()

# %%
X_train[X_train.construction_year != 0].construction_year.describe().round(2)
# Out:
# count    34885.00
# mean      1996.84
# std         12.48
# min       1960.00
# 25%       1988.00
# 50%       2000.00
# 75%       2008.00
# max       2013.00
# Name: construction_year, dtype: float64

# %%
cv_coef = round(12.48 / 1996.84, 2)
cv_coef
# Out:
# 0.01

# %%
X_train.construction_year.isnull().sum()
# Out:
# 0

# %%
X_train.loc[X_train.construction_year == 0, 'construction_year'] = np.nan

# %%
X_train.construction_year.isnull().sum()
# Out:
# 18575

# %% [markdown]
# The mean value of non-zero entries in construction_year -  1997 would seem to be a good candidate for the imputed value of the NaNs in year.
# It's close to the median and there is little variation in this data. Since there are no outliers and the sample mean is an unbiased estmiator of the population mean, it's better to choose the mean over the median for imputing missing values.

# %%
count_values(df = X_train, value = 0)
# Out:
#                Count of 0  0's as % of Total
# Feature
# gps_height          18313               34.3
# district_code          22                0.0
# id                      1                0.0

# %%
X_train[X_train.gps_height == 0]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 44928  31080         0.0    2012-10-10                     Dwe           0
# 955    44490         0.0    2012-10-12                   Rwssp           0
# 46076  37560         0.0    2011-03-15     Mkinga Distric Coun           0
# 11376  12282         0.0    2011-08-07  Government Of Tanzania           0
# 41084   4136         0.0    2011-03-30                     NaN           0
# ...      ...         ...           ...                     ...         ...
# 41090  50530         0.0    2011-03-24              World Bank           0
# 44131   5457         0.0    2011-03-14                     Bsf           0
# 16850  45990        10.0    2011-04-02             Quick Wings           0
# 6265   47858         0.0    2011-03-10                     Bsf           0
# 15795  49444         0.0    2012-10-31                   Rwssp           0
#
#                  installer  longitude      latitude         wpt_name  \
# 44928               WEDECO  33.179596 -4.214966e+00        Hospitali
# 955                  RWSSP  33.071249 -3.803178e+00           Ujamaa
# 46076                  DWE  38.768891 -4.751313e+00   Shabani Wambua
# 11376           Government   0.000000 -2.000000e-08          Bombani
# 41084                  NaN  33.037957 -9.365355e+00       Tingatinga
# ...                    ...        ...           ...              ...
# 41090                Inter  36.644403 -6.249858e+00  Kwa John Makago
# 44131                  DWE  35.238399 -5.172737e+00        Machineni
# 16850  Korogwe water works  38.466952 -5.172985e+00         Kanisani
# 6265                  Gove  35.547568 -6.336433e+00           Mnadan
# 15795               WEDECO  34.316586 -3.107161e+00         Muungano
#
#                basin subvillage     region  region_code  district_code  \
# 44928       Internal    Majengo     Tabora           14              1
# 955    Lake Victoria     Busubi  Shinyanga           17              3
# 46076        Pangani  Kibaoni B      Tanga            4              8
# 11376  Lake Victoria   K/Center     Mwanza           19              6
# 41084     Lake Nyasa      Ibana      Mbeya           12              5
# ...              ...        ...        ...          ...            ...
# 41090    Wami / Ruvu        NaN     Dodoma            1              3
# 44131       Internal  Kilimba B     Dodoma            1              1
# 16850        Pangani    Manzese      Tanga            4              2
# 6265        Internal     Kikuyu     Dodoma            1              6
# 15795  Lake Victoria     Ijosho  Shinyanga           17              6
#
#                    lga         ward  population public_meeting  \
# 44928            Nzega  Nzega Urban         NaN          False
# 955    Shinyanga Rural        Didia         NaN           True
# 46076           Mkinga       Daluni       400.0           True
# 11376            Geita       Kakora         NaN           True
# 41084            Ileje      Chitete         NaN           True
# ...                ...          ...         ...            ...
# 41090           Kongwa         Iduo         NaN           True
# 44131           Kondoa        Ovada         NaN           True
# 16850          Korogwe      Korogwe      1000.0           True
# 6265              Bahi      Ibugule         NaN           True
# 15795            Meatu     Sakasaka         NaN           True
#
#                    recorded_by scheme_management            scheme_name  \
# 44928  GeoData Consultants Ltd   Water authority  Kilimi and uchama dam
# 955    GeoData Consultants Ltd               WUG                    NaN
# 46076  GeoData Consultants Ltd               VWC   Kigongoi gravity wat
# 11376  GeoData Consultants Ltd               VWC             Nyamtukuza
# 41084  GeoData Consultants Ltd               VWC                    NaN
# ...                        ...               ...                    ...
# 41090  GeoData Consultants Ltd               VWC                   Iduo
# 44131  GeoData Consultants Ltd               VWC                   Ovad
# 16850  GeoData Consultants Ltd               VWC                    NaN
# 6265   GeoData Consultants Ltd               VWC                   Nkho
# 15795  GeoData Consultants Ltd               WUG                   None
#
#       permit  construction_year extraction_type extraction_type_group  \
# 44928   True                NaN             ksb           submersible
# 955     True                NaN           other                 other
# 46076   True             2000.0         gravity               gravity
# 11376   True                NaN             ksb           submersible
# 41084  False                NaN     nira/tanira           nira/tanira
# ...      ...                ...             ...                   ...
# 41090  False                NaN     submersible           submersible
# 44131  False                NaN            cemo       other motorpump
# 16850   True             2008.0         afridev               afridev
# 6265    True                NaN            mono                  mono
# 15795   True                NaN     nira/tanira           nira/tanira
#
#       extraction_type_class       management management_group         payment  \
# 44928           submersible  water authority       commercial  pay per bucket
# 955                   other              wug       user-group       never pay
# 46076               gravity              vwc       user-group       never pay
# 11376           submersible              vwc       user-group         unknown
# 41084              handpump              vwc       user-group         unknown
# ...                     ...              ...              ...             ...
# 41090           submersible              vwc       user-group  pay per bucket
# 44131             motorpump              vwc       user-group  pay per bucket
# 16850              handpump              vwc       user-group  pay per bucket
# 6265              motorpump              vwc       user-group  pay per bucket
# 15795              handpump              wug       user-group       never pay
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# 44928   per bucket      coloured       colored  insufficient   insufficient
# 955      never pay          soft          good        enough         enough
# 46076    never pay         salty         salty        enough         enough
# 11376      unknown       unknown       unknown           dry            dry
# 41084      unknown          soft          good  insufficient   insufficient
# ...            ...           ...           ...           ...            ...
# 41090   per bucket         salty         salty           dry            dry
# 44131   per bucket          soft          good        enough         enough
# 16850   per bucket          soft          good  insufficient   insufficient
# 6265    per bucket          soft          good        enough         enough
# 15795    never pay          soft          good        enough         enough
#
#              source   source_type source_class              waterpoint_type  \
# 44928           dam           dam      surface                          dam
# 955    shallow well  shallow well  groundwater                        other
# 46076         other         other      unknown           communal standpipe
# 11376          lake    river/lake      surface                    hand pump
# 41084  shallow well  shallow well  groundwater                    hand pump
# ...             ...           ...          ...                          ...
# 41090   machine dbh      borehole  groundwater  communal standpipe multiple
# 44131   machine dbh      borehole  groundwater           communal standpipe
# 16850  shallow well  shallow well  groundwater                    hand pump
# 6265    machine dbh      borehole  groundwater           communal standpipe
# 15795  shallow well  shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# 44928                   dam
# 955                   other
# 46076    communal standpipe
# 11376             hand pump
# 41084             hand pump
# ...                     ...
# 41090    communal standpipe
# 44131    communal standpipe
# 16850             hand pump
# 6265     communal standpipe
# 15795             hand pump
#
# [18313 rows x 39 columns]

# %% [markdown]
# The zeros in gps_height are not actual values - for example ward Kakora has an elevation of 1200 m, not 0 m
# (https://elevationmap.net/kakora-nyang-wale-tz-1012568019). The zeros represents missing values.

# %%
X_train.loc[X_train.gps_height == 0, 'gps_height'] = np.nan

# %%
X_train.gps_height.isnull().sum()
# Out:
# 18313

# %%
X_train[X_train.district_code == 0].groupby('ward').size()
# Out:
# ward
# Gode Gode     5
# Matomondo    17
# dtype: int64

# %%
X_train.ward.value_counts()
# Out:
# Igosi               276
# Imalinyi            223
# Siha Kati           212
# Mdandu              206
# Nduruma             190
#                    ...
# Mwanga Kaskazini      1
# Ifinga                1
# Chinugulu             1
# Kapilula              1
# Mkumbi                1
# Name: ward, Length: 2089, dtype: int64

# %%
X_train[(X_train.district_code != 0) & (X_train.ward.isin(['Gode Gode', 'Matomondo']))]
# Out:
# Empty DataFrame
# Columns: [id, amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group]
# Index: []

# %%
X_train[X_train.district_code == 0].groupby('region').size()
# Out:
# region
# Dodoma    22
# dtype: int64

# %%
X_train[X_train.district_code == 0].groupby(['region', 'ward', 'subvillage']).size()
# Out:
# region  ward       subvillage
# Dodoma  Gode Gode  Chamwino A      2
#                    Chang'Ombe      1
#                    Ng'Ambo         2
#         Matomondo  Bondeni         2
#                    Ikulu           2
#                    Kaloleni B      2
#                    Majengo         1
#                    Mangwe          2
#                    Manyata         1
#                    Mbuyuni         2
#                    Misheni         1
#                    Misheni B       1
#                    Msunjilile      1
#                    Sangandunghu    1
#                    Shuleni         1
# dtype: int64

# %% [markdown]
# There is just no district code data for couple of villages in Gode Gode and Matomondo wards.

# %%
X_train.loc[X_train.district_code == 0, 'district_code'] = np.nan

# %%
X_train.district_code.isnull().sum()
# Out:
# 22

# %%
count_values(df = X_train, value = 0)
# Out:
#          Count of 0  0's as % of Total
# Feature
# id                1                0.0

# %%
(X_train.isnull().sum().sort_values(ascending = False) / len(X_train)).round(2).head(10)
# Out:
# scheme_name          0.47
# population           0.36
# construction_year    0.35
# gps_height           0.34
# scheme_management    0.06
# installer            0.06
# funder               0.06
# public_meeting       0.06
# permit               0.05
# subvillage           0.01
# dtype: float64

# %%
len(X_train) == len(y_train)
# Out:
# True

# %%
X_train.index
# Out:
# Int64Index([44928, 31178,  9485,   955, 29186, 46076, 11376, 41084, 46319,
#             39251,
#             ...
#             16850,  6265, 54886, 11284, 44732, 54343, 38158,   860, 15795,
#             56422],
#            dtype='int64', length=53460)

# %%
y_train.index
# Out:
# Int64Index([31080, 17282, 72545, 44490, 67816, 37560, 12282,  4136, 40776,
#             61121,
#             ...
#             45990, 47858, 15504, 46009, 51225, 68525, 11980, 35778, 49444,
#             23812],
#            dtype='int64', name='id', length=53460)

# %%
X_train.head()
# Out:
#           id  amount_tsh date_recorded      funder  gps_height installer  \
# 44928  31080         0.0    2012-10-10         Dwe         NaN    WEDECO
# 31178  17282        50.0    2013-02-16       Jaica       -33.0     Tasaf
# 9485   72545         0.0    2011-03-20         Dhv       298.0       DWE
# 955    44490         0.0    2012-10-12       Rwssp         NaN     RWSSP
# 29186  67816         5.0    2013-02-04  Ces (gmbh)      1088.0       DWE
#
#        longitude   latitude                 wpt_name                    basin  \
# 44928  33.179596  -4.214966                Hospitali                 Internal
# 31178  40.322805 -10.456297        Kwa Bakari Ismail  Ruvuma / Southern Coast
# 9485   36.353508  -8.780099            Kwa Mgirigiti                   Rufiji
# 955    33.071249  -3.803178                   Ujamaa            Lake Victoria
# 29186  37.271938  -3.283501  Kwa Richard Simon Chami                  Pangani
#
#        subvillage       region  region_code  district_code              lga  \
# 44928     Majengo       Tabora           14            1.0            Nzega
# 31178     Kipingo       Mtwara           99            1.0     Mtwara Rural
# 9485   Kilungwili     Morogoro            5            4.0           Ulanga
# 955        Busubi    Shinyanga           17            3.0  Shinyanga Rural
# 29186      Muyuni  Kilimanjaro            3            4.0      Moshi Rural
#
#               ward  population public_meeting              recorded_by  \
# 44928  Nzega Urban         NaN          False  GeoData Consultants Ltd
# 31178    Mahurunga      1000.0           True  GeoData Consultants Ltd
# 9485      Mtimbira         1.0           True  GeoData Consultants Ltd
# 955          Didia         NaN           True  GeoData Consultants Ltd
# 29186        Kindi        50.0           True  GeoData Consultants Ltd
#
#       scheme_management                  scheme_name permit  \
# 44928   Water authority        Kilimi and uchama dam   True
# 31178               VWC         Tangazo water supply   True
# 9485                NaN                          NaN   True
# 955                 WUG                          NaN   True
# 29186       Water Board  Lyamungo umbwe water supply   True
#
#        construction_year extraction_type extraction_type_group  \
# 44928                NaN             ksb           submersible
# 31178             2008.0     submersible           submersible
# 9485              1991.0           other                 other
# 955                  NaN           other                 other
# 29186             2007.0         gravity               gravity
#
#       extraction_type_class       management management_group         payment  \
# 44928           submersible  water authority       commercial  pay per bucket
# 31178           submersible              vwc       user-group  pay per bucket
# 9485                  other              wug       user-group       never pay
# 955                   other              wug       user-group       never pay
# 29186               gravity      water board       user-group  pay per bucket
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# 44928   per bucket      coloured       colored  insufficient   insufficient
# 31178   per bucket         salty         salty        enough         enough
# 9485     never pay          soft          good  insufficient   insufficient
# 955      never pay          soft          good        enough         enough
# 29186   per bucket          soft          good        enough         enough
#
#              source   source_type source_class              waterpoint_type  \
# 44928           dam           dam      surface                          dam
# 31178   machine dbh      borehole  groundwater  communal standpipe multiple
# 9485   shallow well  shallow well  groundwater                        other
# 955    shallow well  shallow well  groundwater                        other
# 29186         river    river/lake      surface           communal standpipe
#
#       waterpoint_type_group
# 44928                   dam
# 31178    communal standpipe
# 9485                  other
# 955                   other
# 29186    communal standpipe

# %%
y_train.head()
# Out:
#          status_group
# id
# 31080      functional
# 17282  non functional
# 72545  non functional
# 44490  non functional
# 67816      functional

# %%
Xy_train = X_train.merge(y_train.reset_index(), how = 'inner')

# %%
Xy_train.head()
# Out:
#       id  amount_tsh date_recorded      funder  gps_height installer  \
# 0  31080         0.0    2012-10-10         Dwe         NaN    WEDECO
# 1  17282        50.0    2013-02-16       Jaica       -33.0     Tasaf
# 2  72545         0.0    2011-03-20         Dhv       298.0       DWE
# 3  44490         0.0    2012-10-12       Rwssp         NaN     RWSSP
# 4  67816         5.0    2013-02-04  Ces (gmbh)      1088.0       DWE
#
#    longitude   latitude                 wpt_name                    basin  \
# 0  33.179596  -4.214966                Hospitali                 Internal
# 1  40.322805 -10.456297        Kwa Bakari Ismail  Ruvuma / Southern Coast
# 2  36.353508  -8.780099            Kwa Mgirigiti                   Rufiji
# 3  33.071249  -3.803178                   Ujamaa            Lake Victoria
# 4  37.271938  -3.283501  Kwa Richard Simon Chami                  Pangani
#
#    subvillage       region  region_code  district_code              lga  \
# 0     Majengo       Tabora           14            1.0            Nzega
# 1     Kipingo       Mtwara           99            1.0     Mtwara Rural
# 2  Kilungwili     Morogoro            5            4.0           Ulanga
# 3      Busubi    Shinyanga           17            3.0  Shinyanga Rural
# 4      Muyuni  Kilimanjaro            3            4.0      Moshi Rural
#
#           ward  population public_meeting              recorded_by  \
# 0  Nzega Urban         NaN          False  GeoData Consultants Ltd
# 1    Mahurunga      1000.0           True  GeoData Consultants Ltd
# 2     Mtimbira         1.0           True  GeoData Consultants Ltd
# 3        Didia         NaN           True  GeoData Consultants Ltd
# 4        Kindi        50.0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0   Water authority        Kilimi and uchama dam   True                NaN
# 1               VWC         Tangazo water supply   True             2008.0
# 2               NaN                          NaN   True             1991.0
# 3               WUG                          NaN   True                NaN
# 4       Water Board  Lyamungo umbwe water supply   True             2007.0
#
#   extraction_type extraction_type_group extraction_type_class  \
# 0             ksb           submersible           submersible
# 1     submersible           submersible           submersible
# 2           other                 other                 other
# 3           other                 other                 other
# 4         gravity               gravity               gravity
#
#         management management_group         payment payment_type  \
# 0  water authority       commercial  pay per bucket   per bucket
# 1              vwc       user-group  pay per bucket   per bucket
# 2              wug       user-group       never pay    never pay
# 3              wug       user-group       never pay    never pay
# 4      water board       user-group  pay per bucket   per bucket
#
#   water_quality quality_group      quantity quantity_group        source  \
# 0      coloured       colored  insufficient   insufficient           dam
# 1         salty         salty        enough         enough   machine dbh
# 2          soft          good  insufficient   insufficient  shallow well
# 3          soft          good        enough         enough  shallow well
# 4          soft          good        enough         enough         river
#
#     source_type source_class              waterpoint_type  \
# 0           dam      surface                          dam
# 1      borehole  groundwater  communal standpipe multiple
# 2  shallow well  groundwater                        other
# 3  shallow well  groundwater                        other
# 4    river/lake      surface           communal standpipe
#
#   waterpoint_type_group    status_group
# 0                   dam      functional
# 1    communal standpipe  non functional
# 2                 other  non functional
# 3                 other  non functional
# 4    communal standpipe      functional

# %% [markdown]
# <center>Looking at the distribution of labels</center>

# %%
Xy_train.status_group.value_counts(normalize = True).plot.bar()
plt.grid()
plt.title('The distribution of the response variable')
plt.ylabel('Fraction of waterpoints')
plt.xlabel('Waterpoint condition')
plt.show()

# %% [markdown]
# # How do the numeric features vary with the response variable ?

# %%
Xy_train_num = Xy_train[[c for c in Xy_train.columns if Xy_train[c].dtype in ['int64', 'float64']] + ['status_group']]

# %%
Xy_train_num
# Out:
#           id  amount_tsh  gps_height  longitude   latitude  region_code  \
# 0      31080         0.0         NaN  33.179596  -4.214966           14
# 1      17282        50.0       -33.0  40.322805 -10.456297           99
# 2      72545         0.0       298.0  36.353508  -8.780099            5
# 3      44490         0.0         NaN  33.071249  -3.803178           17
# 4      67816         5.0      1088.0  37.271938  -3.283501            3
# ...      ...         ...         ...        ...        ...          ...
# 53455  68525      1000.0       327.0  36.367112  -8.774761            5
# 53456  11980      1000.0      1743.0  34.531524  -9.769604           11
# 53457  35778         0.0       -13.0  38.974416  -5.420823            4
# 53458  49444         0.0         NaN  34.316586  -3.107161           17
# 53459  23812         0.0      1290.0  37.626401  -3.211457            3
#
#        district_code  population  construction_year    status_group
# 0                1.0         NaN                NaN      functional
# 1                1.0      1000.0             2008.0  non functional
# 2                4.0         1.0             1991.0  non functional
# 3                3.0         NaN                NaN  non functional
# 4                4.0        50.0             2007.0      functional
# ...              ...         ...                ...             ...
# 53455            4.0       255.0             1995.0      functional
# 53456            5.0        35.0             1988.0      functional
# 53457            5.0      1000.0             2005.0  non functional
# 53458            6.0         NaN                NaN      functional
# 53459            1.0         1.0             1976.0  non functional
#
# [53460 rows x 10 columns]

# %%
count_values(df = Xy_train, value = 0.0)
# Out:
#             Count of 0.0  0.0's as % of Total
# Feature
# amount_tsh         37474                 70.1
# longitude           1621                  3.0

# %%
def plot_seaborn_box(x, y, data, title = None, xlabel = None,\
                     ylabel = None, grid = True,\
                    xticks = None, yticks = None, figsize = None) :
    
    """
    
    Example
    -------
    sns.boxplot(y = 'construction_year', x = 'status_group', data = Xy_train_num)
    """
    
    if xlabel :
        plt.xlabel(xlabel)
    
    if ylabel :
        plt.ylabel(ylabel)
    
    if title :
        plt.title(title)
    
    if xticks :
        plt.xticks(xticks)
        
    if yticks :
        plt.yticks(yticks)
    
    sns.boxplot(y = y, x = x, data = data)
    plt.show()

# %%
for c in Xy_train_num.columns :
    if (c not in ['status_group', 'id']) & ('code' not in c) :
        print()
        plot_seaborn_box(y = c, x = 'status_group', data = Xy_train_num,\
                         title = 'Distribution of {} across different status groups'\
                         .format(c))
        print()

# %% [markdown]
# Based on the boxplots above we find :
# - Amount_tsh (amount of water in the well) contain extreme values which distort the distribution and must be explored further
# - Functional waterpoints have a median height of about 1250 m compared to 1000 m for non functional ones
# - Tanzania is between 29 and 40 degrees East (checked on Web), so any entries whose longitude are not in this range must be incorrect. There are such entries, so they should be treated as NaNs
# - There may be incorrect entries in latitude, since there are values as high as 0, whereas Tanzania latitude ranges approxmiately from -1 to -12.5
# - The distribution of population needs to be examined more thorougly as the potentiall outliers distort the image

# %%
Xy_train.population.describe().round(2)
# Out:
# count    34271.00
# mean       279.96
# std        561.79
# min          1.00
# 25%         40.00
# 50%        150.00
# 75%        324.50
# max      30500.00
# Name: population, dtype: float64

# %%
Xy_train.groupby('status_group').population.describe().round(2)
# Out:
#                            count    mean     std  min   25%    50%    75%  \
# status_group
# functional               18941.0  285.46  605.86  1.0  45.0  150.0  312.0
# functional needs repair   2290.0  301.62  532.68  1.0  60.0  200.0  400.0
# non functional           13040.0  268.17  496.23  1.0   1.0  150.0  320.0
#
#                              max
# status_group
# functional               30500.0
# functional needs repair  15300.0
# non functional            9865.0

# %%
sns.kdeplot(x = 'population', data = Xy_train)
plt.title('Distribution of population size around waterpoints')
plt.show()

# %%
Xy_train.population.plot.hist(bins = 50)
plt.xlabel('Population')
plt.ylabel('Count')
plt.title('Distribution of population size around waterpoints')
plt.xlim((0, 11000))
plt.xticks([*range(0, 11000, 1000)])
plt.grid()
plt.show()

# %%
#pop = pd.read_csv('sample10population_above_5000.csv')
#= Xy_train[Xy_train.population > 5000].sample(n = 10)

# %% [markdown]
# On inspecting random 10 population entries above 5000 peeple the data seem more or less plausible, since the population around the well is always less than the actual population of the whole ward and is not so extreme.

# %%
Xy_train[Xy_train.population > 10000]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 6425   30750        50.0    2011-03-04                    Wsdp        26.0
# 10884  12169         NaN    2011-03-12  Government Of Tanzania       184.0
# 45975  49354         NaN    2013-02-21             Water Board      1084.0
#
#          installer  longitude  latitude   wpt_name        basin   subvillage  \
# 6425           DWE  38.727663 -6.724701    Msagasa  Wami / Ruvu  Kilangalang
# 10884          DWE  38.783756 -5.181904   Mkwajuni      Pangani     Mkwajuni
# 45975  Water board  36.386050 -4.787678  Mashineni     Internal  Engarakashi
#
#         region  region_code  district_code     lga      ward  population  \
# 6425     Pwani            6            2.0  Kibaha  Mlandizi     11463.0
# 10884    Tanga            4            3.0  Muheza  Masuguru     30500.0
# 45975  Manyara           21            5.0  Kiteto    Makame     15300.0
#
#       public_meeting              recorded_by scheme_management  scheme_name  \
# 6425            True  GeoData Consultants Ltd               VWC     Borehole
# 10884           True  GeoData Consultants Ltd               VWC          NaN
# 45975           True  GeoData Consultants Ltd               VWC  Water board
#
#       permit  construction_year extraction_type extraction_type_group  \
# 6425    True             2006.0            mono                  mono
# 10884  False             2008.0     nira/tanira           nira/tanira
# 45975  False             1983.0     submersible           submersible
#
#       extraction_type_class management management_group         payment  \
# 6425              motorpump        vwc       user-group  pay per bucket
# 10884              handpump        vwc       user-group       never pay
# 45975           submersible        vwc       user-group       never pay
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# 6425    per bucket          soft          good        enough         enough
# 10884    never pay         salty         salty  insufficient   insufficient
# 45975    never pay          soft          good  insufficient   insufficient
#
#              source   source_type source_class     waterpoint_type  \
# 6425          river    river/lake      surface  communal standpipe
# 10884  shallow well  shallow well  groundwater           hand pump
# 45975   machine dbh      borehole  groundwater  communal standpipe
#
#       waterpoint_type_group             status_group
# 6425     communal standpipe               functional
# 10884             hand pump               functional
# 45975    communal standpipe  functional needs repair

# %% [markdown]
# Mkwajuni had a population of 22K back in 2002 so it's conceivable that it grew by 8500 or 39 % over the next 10 years.

# %% [markdown]
# https://en.wikipedia.org/wiki/Mkwajuni#:~:text=Mkwajuni%20is%20an%20administrative%20ward,a%20total%20population%20of%2022%2C101.

# %% [markdown]
# It seems that the values in population are on the whole correct.

# %%
Xy_train[Xy_train.latitude > - 0.9]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 6      12282         NaN    2011-08-07  Government Of Tanzania         NaN
# 12     56023         NaN    2011-07-18  Government Of Tanzania         NaN
# 19     26944         NaN    2011-07-30                  Hesawa         NaN
# 83     45957         NaN    2011-07-24                  Tanapa         NaN
# 111    16593         NaN    2011-08-26  Government Of Tanzania         NaN
# ...      ...         ...           ...                     ...         ...
# 53334  30428         NaN    2013-02-16                    Dwsp         NaN
# 53345  60259         NaN    2011-07-19                  Hesawa         NaN
# 53348  55213         NaN    2012-10-24                  Hesawa         NaN
# 53359  30192         NaN    2011-08-12                  Hesawa         NaN
# 53386   3854         NaN    2012-10-26                 Holland         NaN
#
#         installer  longitude      latitude    wpt_name            basin  \
# 6      Government        NaN -2.000000e-08     Bombani    Lake Victoria
# 12     Government        NaN -2.000000e-08    Hospital    Lake Victoria
# 19            DWE        NaN -2.000000e-08     Bombani    Lake Victoria
# 83         TANAPA        NaN -2.000000e-08       Jamii    Lake Victoria
# 111    Government        NaN -2.000000e-08     Shabani    Lake Victoria
# ...           ...        ...           ...         ...              ...
# 53334         DWE        NaN -2.000000e-08    Muungano    Lake Victoria
# 53345         DWE        NaN -2.000000e-08       Maige    Lake Victoria
# 53348         DWE        NaN -2.000000e-08  Kwa Kanuti    Lake Victoria
# 53359         DWE        NaN -2.000000e-08      Ezekia  Lake Tanganyika
# 53386     HOLLAND        NaN -2.000000e-08       Jamii    Lake Victoria
#
#       subvillage     region  region_code  district_code      lga  \
# 6       K/Center     Mwanza           19            6.0    Geita
# 12        Nyanza     Mwanza           19            6.0    Geita
# 19      Ushirika     Mwanza           19            6.0    Geita
# 83      Mwamongo  Shinyanga           17            1.0  Bariadi
# 111      Majengo     Mwanza           19            6.0    Geita
# ...          ...        ...          ...            ...      ...
# 53334    Nyamswa  Shinyanga           17            1.0  Bariadi
# 53345    Katundu     Mwanza           19            6.0    Geita
# 53348      Selya     Mwanza           19            2.0     Magu
# 53359      Mraba     Mwanza           19            6.0    Geita
# 53386     Habare     Mwanza           17            1.0     Magu
#
#                ward  population public_meeting              recorded_by  \
# 6            Kakora         NaN           True  GeoData Consultants Ltd
# 12      Kalangalala         NaN           True  GeoData Consultants Ltd
# 19          Kasamwa         NaN           True  GeoData Consultants Ltd
# 83         Mwaswale         NaN          False  GeoData Consultants Ltd
# 111    Nyachiluluma         NaN           True  GeoData Consultants Ltd
# ...             ...         ...            ...                      ...
# 53334        Mhango         NaN            NaN  GeoData Consultants Ltd
# 53345   Kalangalala         NaN           True  GeoData Consultants Ltd
# 53348    Mwananyili         NaN           True  GeoData Consultants Ltd
# 53359      Mwingiro         NaN           True  GeoData Consultants Ltd
# 53386      Nkungulu         NaN            NaN  GeoData Consultants Ltd
#
#       scheme_management  scheme_name permit  construction_year  \
# 6                   VWC   Nyamtukuza   True                NaN
# 12                  VWC  Kalangalala   True                NaN
# 19                  VWC          NaN   True                NaN
# 83           Parastatal          NaN  False                NaN
# 111                 VWC          NaN   True                NaN
# ...                 ...          ...    ...                ...
# 53334               WUG          NaN  False                NaN
# 53345               VWC          NaN   True                NaN
# 53348               VWC          NaN   True                NaN
# 53359               VWC          NaN   True                NaN
# 53386               WUG          NaN  False                NaN
#
#       extraction_type extraction_type_group extraction_type_class  management  \
# 6                 ksb           submersible           submersible         vwc
# 12        submersible           submersible           submersible         vwc
# 19        nira/tanira           nira/tanira              handpump         vwc
# 83              other                 other                 other  parastatal
# 111               ksb           submersible           submersible         vwc
# ...               ...                   ...                   ...         ...
# 53334     nira/tanira           nira/tanira              handpump         wug
# 53345     nira/tanira           nira/tanira              handpump         vwc
# 53348     nira/tanira           nira/tanira              handpump         vwc
# 53359     nira/tanira           nira/tanira              handpump         vwc
# 53386          swn 80                swn 80              handpump         wug
#
#       management_group         payment payment_type water_quality  \
# 6           user-group         unknown      unknown       unknown
# 12          user-group       never pay    never pay          soft
# 19          user-group         unknown      unknown       unknown
# 83          parastatal       never pay    never pay          soft
# 111         user-group       never pay    never pay       unknown
# ...                ...             ...          ...           ...
# 53334       user-group         unknown      unknown          soft
# 53345       user-group  pay per bucket   per bucket          soft
# 53348       user-group       never pay    never pay          soft
# 53359       user-group       never pay    never pay          soft
# 53386       user-group         unknown      unknown          soft
#
#       quality_group      quantity quantity_group        source   source_type  \
# 6           unknown           dry            dry          lake    river/lake
# 12             good  insufficient   insufficient        spring        spring
# 19          unknown           dry            dry  shallow well  shallow well
# 83             good           dry            dry  shallow well  shallow well
# 111         unknown           dry            dry          lake    river/lake
# ...             ...           ...            ...           ...           ...
# 53334          good        enough         enough  shallow well  shallow well
# 53345          good  insufficient   insufficient  shallow well  shallow well
# 53348          good        enough         enough  shallow well  shallow well
# 53359          good  insufficient   insufficient  shallow well  shallow well
# 53386          good        enough         enough  shallow well  shallow well
#
#       source_class              waterpoint_type waterpoint_type_group  \
# 6          surface                    hand pump             hand pump
# 12     groundwater                    hand pump             hand pump
# 19     groundwater                    hand pump             hand pump
# 83     groundwater                    hand pump             hand pump
# 111        surface  communal standpipe multiple    communal standpipe
# ...            ...                          ...                   ...
# 53334  groundwater                    hand pump             hand pump
# 53345  groundwater                    hand pump             hand pump
# 53348  groundwater                    hand pump             hand pump
# 53359  groundwater                    hand pump             hand pump
# 53386  groundwater                    hand pump             hand pump
#
#          status_group
# 6      non functional
# 12         functional
# 19     non functional
# 83     non functional
# 111    non functional
# ...               ...
# 53334      functional
# 53345      functional
# 53348  non functional
# 53359      functional
# 53386  non functional
#
# [1621 rows x 40 columns]

# %%
print('Some latitudes have a format like this : {}. It"s type is {}'\
      .format(Xy_train[Xy_train.id == 12282].latitude.iloc[0], type(Xy_train[Xy_train.id == 12282].latitude.iloc[0])))
# Out:
# Some latitudes have a format like this : -2e-08. It"s type is <class 'numpy.float64'>

# %%
Xy_train[Xy_train.latitude.astype(str).str.contains('-2e-08')]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 6      12282         NaN    2011-08-07  Government Of Tanzania         NaN
# 12     56023         NaN    2011-07-18  Government Of Tanzania         NaN
# 19     26944         NaN    2011-07-30                  Hesawa         NaN
# 83     45957         NaN    2011-07-24                  Tanapa         NaN
# 111    16593         NaN    2011-08-26  Government Of Tanzania         NaN
# ...      ...         ...           ...                     ...         ...
# 53334  30428         NaN    2013-02-16                    Dwsp         NaN
# 53345  60259         NaN    2011-07-19                  Hesawa         NaN
# 53348  55213         NaN    2012-10-24                  Hesawa         NaN
# 53359  30192         NaN    2011-08-12                  Hesawa         NaN
# 53386   3854         NaN    2012-10-26                 Holland         NaN
#
#         installer  longitude      latitude    wpt_name            basin  \
# 6      Government        NaN -2.000000e-08     Bombani    Lake Victoria
# 12     Government        NaN -2.000000e-08    Hospital    Lake Victoria
# 19            DWE        NaN -2.000000e-08     Bombani    Lake Victoria
# 83         TANAPA        NaN -2.000000e-08       Jamii    Lake Victoria
# 111    Government        NaN -2.000000e-08     Shabani    Lake Victoria
# ...           ...        ...           ...         ...              ...
# 53334         DWE        NaN -2.000000e-08    Muungano    Lake Victoria
# 53345         DWE        NaN -2.000000e-08       Maige    Lake Victoria
# 53348         DWE        NaN -2.000000e-08  Kwa Kanuti    Lake Victoria
# 53359         DWE        NaN -2.000000e-08      Ezekia  Lake Tanganyika
# 53386     HOLLAND        NaN -2.000000e-08       Jamii    Lake Victoria
#
#       subvillage     region  region_code  district_code      lga  \
# 6       K/Center     Mwanza           19            6.0    Geita
# 12        Nyanza     Mwanza           19            6.0    Geita
# 19      Ushirika     Mwanza           19            6.0    Geita
# 83      Mwamongo  Shinyanga           17            1.0  Bariadi
# 111      Majengo     Mwanza           19            6.0    Geita
# ...          ...        ...          ...            ...      ...
# 53334    Nyamswa  Shinyanga           17            1.0  Bariadi
# 53345    Katundu     Mwanza           19            6.0    Geita
# 53348      Selya     Mwanza           19            2.0     Magu
# 53359      Mraba     Mwanza           19            6.0    Geita
# 53386     Habare     Mwanza           17            1.0     Magu
#
#                ward  population public_meeting              recorded_by  \
# 6            Kakora         NaN           True  GeoData Consultants Ltd
# 12      Kalangalala         NaN           True  GeoData Consultants Ltd
# 19          Kasamwa         NaN           True  GeoData Consultants Ltd
# 83         Mwaswale         NaN          False  GeoData Consultants Ltd
# 111    Nyachiluluma         NaN           True  GeoData Consultants Ltd
# ...             ...         ...            ...                      ...
# 53334        Mhango         NaN            NaN  GeoData Consultants Ltd
# 53345   Kalangalala         NaN           True  GeoData Consultants Ltd
# 53348    Mwananyili         NaN           True  GeoData Consultants Ltd
# 53359      Mwingiro         NaN           True  GeoData Consultants Ltd
# 53386      Nkungulu         NaN            NaN  GeoData Consultants Ltd
#
#       scheme_management  scheme_name permit  construction_year  \
# 6                   VWC   Nyamtukuza   True                NaN
# 12                  VWC  Kalangalala   True                NaN
# 19                  VWC          NaN   True                NaN
# 83           Parastatal          NaN  False                NaN
# 111                 VWC          NaN   True                NaN
# ...                 ...          ...    ...                ...
# 53334               WUG          NaN  False                NaN
# 53345               VWC          NaN   True                NaN
# 53348               VWC          NaN   True                NaN
# 53359               VWC          NaN   True                NaN
# 53386               WUG          NaN  False                NaN
#
#       extraction_type extraction_type_group extraction_type_class  management  \
# 6                 ksb           submersible           submersible         vwc
# 12        submersible           submersible           submersible         vwc
# 19        nira/tanira           nira/tanira              handpump         vwc
# 83              other                 other                 other  parastatal
# 111               ksb           submersible           submersible         vwc
# ...               ...                   ...                   ...         ...
# 53334     nira/tanira           nira/tanira              handpump         wug
# 53345     nira/tanira           nira/tanira              handpump         vwc
# 53348     nira/tanira           nira/tanira              handpump         vwc
# 53359     nira/tanira           nira/tanira              handpump         vwc
# 53386          swn 80                swn 80              handpump         wug
#
#       management_group         payment payment_type water_quality  \
# 6           user-group         unknown      unknown       unknown
# 12          user-group       never pay    never pay          soft
# 19          user-group         unknown      unknown       unknown
# 83          parastatal       never pay    never pay          soft
# 111         user-group       never pay    never pay       unknown
# ...                ...             ...          ...           ...
# 53334       user-group         unknown      unknown          soft
# 53345       user-group  pay per bucket   per bucket          soft
# 53348       user-group       never pay    never pay          soft
# 53359       user-group       never pay    never pay          soft
# 53386       user-group         unknown      unknown          soft
#
#       quality_group      quantity quantity_group        source   source_type  \
# 6           unknown           dry            dry          lake    river/lake
# 12             good  insufficient   insufficient        spring        spring
# 19          unknown           dry            dry  shallow well  shallow well
# 83             good           dry            dry  shallow well  shallow well
# 111         unknown           dry            dry          lake    river/lake
# ...             ...           ...            ...           ...           ...
# 53334          good        enough         enough  shallow well  shallow well
# 53345          good  insufficient   insufficient  shallow well  shallow well
# 53348          good        enough         enough  shallow well  shallow well
# 53359          good  insufficient   insufficient  shallow well  shallow well
# 53386          good        enough         enough  shallow well  shallow well
#
#       source_class              waterpoint_type waterpoint_type_group  \
# 6          surface                    hand pump             hand pump
# 12     groundwater                    hand pump             hand pump
# 19     groundwater                    hand pump             hand pump
# 83     groundwater                    hand pump             hand pump
# 111        surface  communal standpipe multiple    communal standpipe
# ...            ...                          ...                   ...
# 53334  groundwater                    hand pump             hand pump
# 53345  groundwater                    hand pump             hand pump
# 53348  groundwater                    hand pump             hand pump
# 53359  groundwater                    hand pump             hand pump
# 53386  groundwater                    hand pump             hand pump
#
#          status_group
# 6      non functional
# 12         functional
# 19     non functional
# 83     non functional
# 111    non functional
# ...               ...
# 53334      functional
# 53345      functional
# 53348  non functional
# 53359      functional
# 53386  non functional
#
# [1621 rows x 40 columns]

# %%
Xy_train.loc[Xy_train.latitude.astype(str).str.contains('-2e-08'), 'latitude'] = np.nan

# %%
(Xy_train.isnull().sum().sort_values(ascending = False) / len(Xy_train)).round(2).head(15)
# Out:
# amount_tsh           0.70
# scheme_name          0.47
# population           0.36
# construction_year    0.35
# gps_height           0.34
# scheme_management    0.06
# installer            0.06
# funder               0.06
# public_meeting       0.06
# permit               0.05
# longitude            0.03
# latitude             0.03
# subvillage           0.01
# district_code        0.00
# quantity_group       0.00
# dtype: float64

# %%
Xy_train.head()
# Out:
#       id  amount_tsh date_recorded      funder  gps_height installer  \
# 0  31080         0.0    2012-10-10         Dwe         NaN    WEDECO
# 1  17282        50.0    2013-02-16       Jaica       -33.0     Tasaf
# 2  72545         0.0    2011-03-20         Dhv       298.0       DWE
# 3  44490         0.0    2012-10-12       Rwssp         NaN     RWSSP
# 4  67816         5.0    2013-02-04  Ces (gmbh)      1088.0       DWE
#
#    longitude   latitude                 wpt_name                    basin  \
# 0  33.179596  -4.214966                Hospitali                 Internal
# 1  40.322805 -10.456297        Kwa Bakari Ismail  Ruvuma / Southern Coast
# 2  36.353508  -8.780099            Kwa Mgirigiti                   Rufiji
# 3  33.071249  -3.803178                   Ujamaa            Lake Victoria
# 4  37.271938  -3.283501  Kwa Richard Simon Chami                  Pangani
#
#    subvillage       region  region_code  district_code              lga  \
# 0     Majengo       Tabora           14            1.0            Nzega
# 1     Kipingo       Mtwara           99            1.0     Mtwara Rural
# 2  Kilungwili     Morogoro            5            4.0           Ulanga
# 3      Busubi    Shinyanga           17            3.0  Shinyanga Rural
# 4      Muyuni  Kilimanjaro            3            4.0      Moshi Rural
#
#           ward  population public_meeting              recorded_by  \
# 0  Nzega Urban         NaN          False  GeoData Consultants Ltd
# 1    Mahurunga      1000.0           True  GeoData Consultants Ltd
# 2     Mtimbira         1.0           True  GeoData Consultants Ltd
# 3        Didia         NaN           True  GeoData Consultants Ltd
# 4        Kindi        50.0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0   Water authority        Kilimi and uchama dam   True                NaN
# 1               VWC         Tangazo water supply   True             2008.0
# 2               NaN                          NaN   True             1991.0
# 3               WUG                          NaN   True                NaN
# 4       Water Board  Lyamungo umbwe water supply   True             2007.0
#
#   extraction_type extraction_type_group extraction_type_class  \
# 0             ksb           submersible           submersible
# 1     submersible           submersible           submersible
# 2           other                 other                 other
# 3           other                 other                 other
# 4         gravity               gravity               gravity
#
#         management management_group         payment payment_type  \
# 0  water authority       commercial  pay per bucket   per bucket
# 1              vwc       user-group  pay per bucket   per bucket
# 2              wug       user-group       never pay    never pay
# 3              wug       user-group       never pay    never pay
# 4      water board       user-group  pay per bucket   per bucket
#
#   water_quality quality_group      quantity quantity_group        source  \
# 0      coloured       colored  insufficient   insufficient           dam
# 1         salty         salty        enough         enough   machine dbh
# 2          soft          good  insufficient   insufficient  shallow well
# 3          soft          good        enough         enough  shallow well
# 4          soft          good        enough         enough         river
#
#     source_type source_class              waterpoint_type  \
# 0           dam      surface                          dam
# 1      borehole  groundwater  communal standpipe multiple
# 2  shallow well  groundwater                        other
# 3  shallow well  groundwater                        other
# 4    river/lake      surface           communal standpipe
#
#   waterpoint_type_group    status_group
# 0                   dam      functional
# 1    communal standpipe  non functional
# 2                 other  non functional
# 3                 other  non functional
# 4    communal standpipe      functional

# %%
Xy_train[(Xy_train.longitude > 40.5) | (Xy_train.longitude < 28.5)]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 6      12282         0.0    2011-08-07  Government Of Tanzania         NaN
# 12     56023         0.0    2011-07-18  Government Of Tanzania         NaN
# 19     26944         0.0    2011-07-30                  Hesawa         NaN
# 83     45957         0.0    2011-07-24                  Tanapa         NaN
# 111    16593         0.0    2011-08-26  Government Of Tanzania         NaN
# ...      ...         ...           ...                     ...         ...
# 53334  30428         0.0    2013-02-16                    Dwsp         NaN
# 53345  60259         0.0    2011-07-19                  Hesawa         NaN
# 53348  55213         0.0    2012-10-24                  Hesawa         NaN
# 53359  30192         0.0    2011-08-12                  Hesawa         NaN
# 53386   3854         0.0    2012-10-26                 Holland         NaN
#
#         installer  longitude      latitude    wpt_name            basin  \
# 6      Government        0.0 -2.000000e-08     Bombani    Lake Victoria
# 12     Government        0.0 -2.000000e-08    Hospital    Lake Victoria
# 19            DWE        0.0 -2.000000e-08     Bombani    Lake Victoria
# 83         TANAPA        0.0 -2.000000e-08       Jamii    Lake Victoria
# 111    Government        0.0 -2.000000e-08     Shabani    Lake Victoria
# ...           ...        ...           ...         ...              ...
# 53334         DWE        0.0 -2.000000e-08    Muungano    Lake Victoria
# 53345         DWE        0.0 -2.000000e-08       Maige    Lake Victoria
# 53348         DWE        0.0 -2.000000e-08  Kwa Kanuti    Lake Victoria
# 53359         DWE        0.0 -2.000000e-08      Ezekia  Lake Tanganyika
# 53386     HOLLAND        0.0 -2.000000e-08       Jamii    Lake Victoria
#
#       subvillage     region  region_code  district_code      lga  \
# 6       K/Center     Mwanza           19            6.0    Geita
# 12        Nyanza     Mwanza           19            6.0    Geita
# 19      Ushirika     Mwanza           19            6.0    Geita
# 83      Mwamongo  Shinyanga           17            1.0  Bariadi
# 111      Majengo     Mwanza           19            6.0    Geita
# ...          ...        ...          ...            ...      ...
# 53334    Nyamswa  Shinyanga           17            1.0  Bariadi
# 53345    Katundu     Mwanza           19            6.0    Geita
# 53348      Selya     Mwanza           19            2.0     Magu
# 53359      Mraba     Mwanza           19            6.0    Geita
# 53386     Habare     Mwanza           17            1.0     Magu
#
#                ward  population public_meeting              recorded_by  \
# 6            Kakora         NaN           True  GeoData Consultants Ltd
# 12      Kalangalala         NaN           True  GeoData Consultants Ltd
# 19          Kasamwa         NaN           True  GeoData Consultants Ltd
# 83         Mwaswale         NaN          False  GeoData Consultants Ltd
# 111    Nyachiluluma         NaN           True  GeoData Consultants Ltd
# ...             ...         ...            ...                      ...
# 53334        Mhango         NaN            NaN  GeoData Consultants Ltd
# 53345   Kalangalala         NaN           True  GeoData Consultants Ltd
# 53348    Mwananyili         NaN           True  GeoData Consultants Ltd
# 53359      Mwingiro         NaN           True  GeoData Consultants Ltd
# 53386      Nkungulu         NaN            NaN  GeoData Consultants Ltd
#
#       scheme_management  scheme_name permit  construction_year  \
# 6                   VWC   Nyamtukuza   True                NaN
# 12                  VWC  Kalangalala   True                NaN
# 19                  VWC          NaN   True                NaN
# 83           Parastatal          NaN  False                NaN
# 111                 VWC          NaN   True                NaN
# ...                 ...          ...    ...                ...
# 53334               WUG          NaN  False                NaN
# 53345               VWC          NaN   True                NaN
# 53348               VWC          NaN   True                NaN
# 53359               VWC          NaN   True                NaN
# 53386               WUG          NaN  False                NaN
#
#       extraction_type extraction_type_group extraction_type_class  management  \
# 6                 ksb           submersible           submersible         vwc
# 12        submersible           submersible           submersible         vwc
# 19        nira/tanira           nira/tanira              handpump         vwc
# 83              other                 other                 other  parastatal
# 111               ksb           submersible           submersible         vwc
# ...               ...                   ...                   ...         ...
# 53334     nira/tanira           nira/tanira              handpump         wug
# 53345     nira/tanira           nira/tanira              handpump         vwc
# 53348     nira/tanira           nira/tanira              handpump         vwc
# 53359     nira/tanira           nira/tanira              handpump         vwc
# 53386          swn 80                swn 80              handpump         wug
#
#       management_group         payment payment_type water_quality  \
# 6           user-group         unknown      unknown       unknown
# 12          user-group       never pay    never pay          soft
# 19          user-group         unknown      unknown       unknown
# 83          parastatal       never pay    never pay          soft
# 111         user-group       never pay    never pay       unknown
# ...                ...             ...          ...           ...
# 53334       user-group         unknown      unknown          soft
# 53345       user-group  pay per bucket   per bucket          soft
# 53348       user-group       never pay    never pay          soft
# 53359       user-group       never pay    never pay          soft
# 53386       user-group         unknown      unknown          soft
#
#       quality_group      quantity quantity_group        source   source_type  \
# 6           unknown           dry            dry          lake    river/lake
# 12             good  insufficient   insufficient        spring        spring
# 19          unknown           dry            dry  shallow well  shallow well
# 83             good           dry            dry  shallow well  shallow well
# 111         unknown           dry            dry          lake    river/lake
# ...             ...           ...            ...           ...           ...
# 53334          good        enough         enough  shallow well  shallow well
# 53345          good  insufficient   insufficient  shallow well  shallow well
# 53348          good        enough         enough  shallow well  shallow well
# 53359          good  insufficient   insufficient  shallow well  shallow well
# 53386          good        enough         enough  shallow well  shallow well
#
#       source_class              waterpoint_type waterpoint_type_group  \
# 6          surface                    hand pump             hand pump
# 12     groundwater                    hand pump             hand pump
# 19     groundwater                    hand pump             hand pump
# 83     groundwater                    hand pump             hand pump
# 111        surface  communal standpipe multiple    communal standpipe
# ...            ...                          ...                   ...
# 53334  groundwater                    hand pump             hand pump
# 53345  groundwater                    hand pump             hand pump
# 53348  groundwater                    hand pump             hand pump
# 53359  groundwater                    hand pump             hand pump
# 53386  groundwater                    hand pump             hand pump
#
#          status_group
# 6      non functional
# 12         functional
# 19     non functional
# 83     non functional
# 111    non functional
# ...               ...
# 53334      functional
# 53345      functional
# 53348  non functional
# 53359      functional
# 53386  non functional
#
# [1621 rows x 40 columns]

# %%
Xy_train[(Xy_train.longitude > 40.5) | (Xy_train.longitude < 28.5)].longitude.unique()
# Out:
# array([0.])

# %%
long_nans = Xy_train.longitude.isnull().sum()
print(f'Before replacing 0.0 longitude with NaNs there were {long_nans} NaNs')
# Out:
# Before replacing 0.0 longitude with NaNs there were 0 NaNs

# %%
Xy_train.loc[Xy_train.longitude == 0, 'longitude'] = np.nan

# %%
print(f'After replacing 0.0 longitude with NaNs there are {Xy_train.longitude.isnull().sum()} NaNs, so there are {Xy_train.longitude.isnull().sum() - long_nans} additional NaNs')
# Out:
# After replacing 0.0 longitude with NaNs there are 1621 NaNs, so there are 1621 additional NaNs

# %%
(Xy_train.isnull().sum().sort_values(ascending = False) / len(Xy_train)).round(2).head(10)
# Out:
# scheme_name          0.47
# population           0.36
# construction_year    0.35
# gps_height           0.34
# scheme_management    0.06
# installer            0.06
# funder               0.06
# public_meeting       0.06
# permit               0.05
# longitude            0.03
# dtype: float64

# %%
Xy_train.head()
# Out:
#       id  amount_tsh date_recorded      funder  gps_height installer  \
# 0  31080         0.0    2012-10-10         Dwe         NaN    WEDECO
# 1  17282        50.0    2013-02-16       Jaica       -33.0     Tasaf
# 2  72545         0.0    2011-03-20         Dhv       298.0       DWE
# 3  44490         0.0    2012-10-12       Rwssp         NaN     RWSSP
# 4  67816         5.0    2013-02-04  Ces (gmbh)      1088.0       DWE
#
#    longitude   latitude                 wpt_name                    basin  \
# 0  33.179596  -4.214966                Hospitali                 Internal
# 1  40.322805 -10.456297        Kwa Bakari Ismail  Ruvuma / Southern Coast
# 2  36.353508  -8.780099            Kwa Mgirigiti                   Rufiji
# 3  33.071249  -3.803178                   Ujamaa            Lake Victoria
# 4  37.271938  -3.283501  Kwa Richard Simon Chami                  Pangani
#
#    subvillage       region  region_code  district_code              lga  \
# 0     Majengo       Tabora           14            1.0            Nzega
# 1     Kipingo       Mtwara           99            1.0     Mtwara Rural
# 2  Kilungwili     Morogoro            5            4.0           Ulanga
# 3      Busubi    Shinyanga           17            3.0  Shinyanga Rural
# 4      Muyuni  Kilimanjaro            3            4.0      Moshi Rural
#
#           ward  population public_meeting              recorded_by  \
# 0  Nzega Urban         NaN          False  GeoData Consultants Ltd
# 1    Mahurunga      1000.0           True  GeoData Consultants Ltd
# 2     Mtimbira         1.0           True  GeoData Consultants Ltd
# 3        Didia         NaN           True  GeoData Consultants Ltd
# 4        Kindi        50.0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0   Water authority        Kilimi and uchama dam   True                NaN
# 1               VWC         Tangazo water supply   True             2008.0
# 2               NaN                          NaN   True             1991.0
# 3               WUG                          NaN   True                NaN
# 4       Water Board  Lyamungo umbwe water supply   True             2007.0
#
#   extraction_type extraction_type_group extraction_type_class  \
# 0             ksb           submersible           submersible
# 1     submersible           submersible           submersible
# 2           other                 other                 other
# 3           other                 other                 other
# 4         gravity               gravity               gravity
#
#         management management_group         payment payment_type  \
# 0  water authority       commercial  pay per bucket   per bucket
# 1              vwc       user-group  pay per bucket   per bucket
# 2              wug       user-group       never pay    never pay
# 3              wug       user-group       never pay    never pay
# 4      water board       user-group  pay per bucket   per bucket
#
#   water_quality quality_group      quantity quantity_group        source  \
# 0      coloured       colored  insufficient   insufficient           dam
# 1         salty         salty        enough         enough   machine dbh
# 2          soft          good  insufficient   insufficient  shallow well
# 3          soft          good        enough         enough  shallow well
# 4          soft          good        enough         enough         river
#
#     source_type source_class              waterpoint_type  \
# 0           dam      surface                          dam
# 1      borehole  groundwater  communal standpipe multiple
# 2  shallow well  groundwater                        other
# 3  shallow well  groundwater                        other
# 4    river/lake      surface           communal standpipe
#
#   waterpoint_type_group    status_group
# 0                   dam      functional
# 1    communal standpipe  non functional
# 2                 other  non functional
# 3                 other  non functional
# 4    communal standpipe      functional

# %%
count_values(df = Xy_train, value = 0.0)
# Out:
#             Count of 0.0  0.0's as % of Total
# Feature
# amount_tsh         37474                 70.1

# %%
Xy_train[Xy_train.amount_tsh == 0].groupby('recorded_by').size()
# Out:
# recorded_by
# GeoData Consultants Ltd    37474
# dtype: int64

# %%
Xy_train[Xy_train.recorded_by == 'GeoData Consultants Ltd'].amount_tsh.value_counts(normalize = True).round(2).head()
# Out:
# 0.0       0.70
# 500.0     0.05
# 50.0      0.04
# 20.0      0.03
# 1000.0    0.02
# Name: amount_tsh, dtype: float64

# %%
Xy_train[Xy_train.recorded_by != 'GeoData Consultants Ltd']
# Out:
# Empty DataFrame
# Columns: [id, amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group, status_group]
# Index: []

# %%
Xy_train[Xy_train.region != 0].groupby('region')['amount_tsh'].nunique()
# Out:
# region
# Arusha           21
# Dar es Salaam    15
# Dodoma            1
# Iringa           38
# Kagera            1
# Kigoma           26
# Kilimanjaro      38
# Lindi            18
# Manyara          23
# Mara             20
# Mbeya             1
# Morogoro         25
# Mtwara           23
# Mwanza           13
# Pwani            37
# Rukwa            25
# Ruvuma           35
# Shinyanga         7
# Singida          26
# Tabora            1
# Tanga            28
# Name: amount_tsh, dtype: int64

# %%
Xy_train[Xy_train.region != 0].groupby('region')['amount_tsh'].value_counts().groupby('region').sum()
# Out:
# region
# Arusha           3027
# Dar es Salaam     734
# Dodoma           1947
# Iringa           4770
# Kagera           2970
# Kigoma           2533
# Kilimanjaro      3942
# Lindi            1394
# Manyara          1425
# Mara             1765
# Mbeya            4161
# Morogoro         3617
# Mtwara           1565
# Mwanza           2794
# Pwani            2376
# Rukwa            1630
# Ruvuma           2387
# Shinyanga        4469
# Singida          1885
# Tabora           1773
# Tanga            2296
# Name: amount_tsh, dtype: int64

# %%
Xy_train[Xy_train.region != 0].groupby('region')['amount_tsh'].mean()
# Out:
# region
# Arusha            374.256690
# Dar es Salaam     255.386921
# Dodoma              0.000000
# Iringa           1204.581761
# Kagera              0.000000
# Kigoma            351.320568
# Kilimanjaro       257.878095
# Lindi              29.167862
# Manyara           243.181053
# Mara              111.972238
# Mbeya               0.000000
# Morogoro          207.353331
# Mtwara             62.783387
# Mwanza             16.088046
# Pwani             608.158670
# Rukwa             819.677914
# Ruvuma            901.567658
# Shinyanga          12.553144
# Singida           466.456340
# Tabora              0.000000
# Tanga             255.373258
# Name: amount_tsh, dtype: float64

# %%
replace_hidden_nans(Xy_train, nan_symbol = 0.0, col_name = 'amount_tsh')

# %%
Xy_train.amount_tsh.isnull().sum() / len(Xy_train)
# Out:
# 0.7009726898615788

# %%
count_values(df = Xy_train, value = 0.0)
# Out:
# Empty DataFrame
# Columns: [Count of 0.0, 0.0's as % of Total]
# Index: []

# %%
count_values(df = Xy_train, value = 0)
# Out:
#          Count of 0  0's as % of Total
# Feature
# id                1                0.0

# %%
(Xy_train.isnull().sum().sort_values(ascending = False) / len(Xy_train)).round(2).head(13)
# Out:
# amount_tsh           0.70
# scheme_name          0.47
# population           0.36
# construction_year    0.35
# gps_height           0.34
# scheme_management    0.06
# installer            0.06
# funder               0.06
# public_meeting       0.06
# permit               0.05
# longitude            0.03
# subvillage           0.01
# district_code        0.00
# dtype: float64

# %% [markdown]
# <center>Imputing missing values on the train data</center>

# %% [markdown]
# scheme_name :

# %%
def value_counts_head(data, grouper, target, n = 5, m = 5, output = False, normalize = True) :
    
    grouped_val_counts = data.groupby(grouper)[target].value_counts(normalize = normalize)
    
    index = grouped_val_counts.index.levels[0].tolist()
    
    sub_series = []
    
    for i, v in enumerate(index) :
        if i == n - 1 :
            break
        small_series = grouped_val_counts.loc[v].head(m)
        small_series.name = v
        sub_series.append(small_series)
    
    if output :
        return sub_series
    
    for s in sub_series :
        print()
        print('The value counts in {} {} : '.format(grouper, s.name))
        print()
        display(s)
        print()

# %%
def grab_top_value_of_each_series(series_iterab) :

    top_value_by_series_name = {}

    for si in series_iterab :
        top_value_by_series_name[si.name] = (si.head(1).index[0], round(si.head(1).values[0], 3))

    return top_value_by_series_name

# %%
series_iterab = value_counts_head(Xy_train, grouper = 'region', target = 'scheme_name', n = 1000, output = True)
series_iterab
# Out:
# [scheme_name
#  Machumba estate pipe line         0.061977
#  Maambreni gravity water supply    0.042966
#  Nabaiye pipe line                 0.036882
#  Nasula gravity water supply       0.036122
#  Olkokola pipe line                0.027757
#  Name: Arusha, dtype: float64,
#  scheme_name
#  J    0.30
#  M    0.28
#  G    0.24
#  N    0.07
#  S    0.07
#  Name: Dar es Salaam, dtype: float64,
#  scheme_name
#  Ntom    0.027458
#  Cham    0.020434
#  Ihum    0.015326
#  Kwa     0.014687
#  Kise    0.014049
#  Name: Dodoma, dtype: float64,
#  scheme_name
#  wanging'ombe water supply s    0.058824
#  wanging'ombe supply scheme     0.051932
#  mtwango water supply scheme    0.033227
#  Roman                          0.030765
#  imalinyi supply scheme         0.018952
#  Name: Iringa, dtype: float64,
#  scheme_name
#  Kaisho/Isingiro w                    0.066038
#  NCHULOWAIBALE WATER SUPPLY SCHEME    0.056604
#  Nyamitoko  water                     0.036792
#  Kan                                  0.033962
#  B                                    0.030189
#  Name: Kagera, dtype: float64,
#  scheme_name
#  Mkongoro Two    0.083899
#  Mkongoro One    0.072178
#  Mgandazi        0.035780
#  Kasangezi       0.033313
#  Nyachenda       0.025910
#  Name: Kigoma, dtype: float64,
#  scheme_name
#  Uroki-Bomang'ombe water sup              0.050609
#  Kirua kahe gravity water supply trust    0.046549
#  Losaa-Kia water supply                   0.037618
#  Lyamungo umbwe water supply              0.029770
#  Kirua kahe pumping water trust           0.028146
#  Name: Kilimanjaro, dtype: float64,
#  scheme_name
#  GEN Borehole Scheme       0.081940
#  JAICA Borehole Scheme     0.076923
#  Nyangao Water Supply      0.065217
#  Mtandao wa Mabomba        0.038462
#  Sabodo Borehole Scheme    0.038462
#  Name: Lindi, dtype: float64,
#  scheme_name
#  Kijiji                        0.186951
#  Mamire water supply           0.079046
#  Msitu wa tembo pipe scheme    0.051443
#  Nameqhwadiba                  0.037641
#  Gallapo water supply          0.032622
#  Name: Manyara, dtype: float64,
#  scheme_name
#  Mradi wa maji Komuge      0.127660
#  Mradi wa maji Shirati     0.111111
#  Kasahunga piped scheme    0.056738
#  Robanda pumping scheme    0.049645
#  Mradi wa maji vijijini    0.044917
#  Name: Mara, dtype: float64,
#  scheme_name
#  K                              0.286201
#  Ngana water supplied scheme    0.135718
#  Makwale water supplied sche    0.084043
#  M                              0.064736
#  N                              0.063032
#  Name: Mbeya, dtype: float64,
#  scheme_name
#  Ki          0.065097
#  Ikela Wa    0.057479
#  Borehole    0.045706
#  Mtimbira    0.042244
#  Ma          0.033934
#  Name: Morogoro, dtype: float64,
#  scheme_name
#  Borehole                    0.283396
#  Mitema                      0.096130
#  MWS                         0.068664
#  Mbuo mkunwa water supply    0.039950
#  Mnyawi water supply         0.033708
#  Name: Mtwara, dtype: float64,
#  scheme_name
#  None                         0.247853
#  Borehole                     0.137423
#  HESAWA                       0.072393
#  Nyamtukuza                   0.055215
#  Kazilankanda Water Supply    0.050307
#  Name: Mwanza, dtype: float64,
#  scheme_name
#  Chalinze wate         0.353965
#  Bagamoyo wate         0.195358
#  upper Ruvu            0.080271
#  Bagamoyo Wate         0.060928
#  Water from DAWASCO    0.028046
#  Name: Pwani, dtype: float64,
#  scheme_name
#  K                         0.080925
#  Laela group water Supp    0.059730
#  Mtowisa water suply       0.055877
#  Mradi wa maji wa pito     0.053950
#  Kalesha water supply      0.048170
#  Name: Rukwa, dtype: float64,
#  scheme_name
#  DANIDA                              0.196294
#  Government                          0.179822
#  Mradi wa maji wa wino               0.054907
#  Mradi wa maji wa peramiho           0.048044
#  Njalamatata water gravity scheme    0.035690
#  Name: Ruvuma, dtype: float64,
#  scheme_name
#  None                           0.456919
#  Lake Victoria pipe scheme      0.052219
#  Central basin                  0.030026
#  MPEISA                         0.027415
#  Maswa Water  supply program    0.022193
#  Name: Shinyanga, dtype: float64,
#  scheme_name
#  M                       0.181406
#  I                       0.105442
#  U                       0.052154
#  Manyoni water supply    0.047619
#  N                       0.041950
#  Name: Singida, dtype: float64,
#  scheme_name
#  World Bank                  0.132723
#  Mradi wa maji wa sikonge    0.057208
#  ADP Simbo                   0.050343
#  Mradi wa maji wa Ipole      0.050343
#  Kilimi and uchama dam       0.048055
#  Name: Tabora, dtype: float64,
#  scheme_name
#  Handeni Trunk Main(H    0.081996
#  Shallow well            0.049911
#  Mlomboza forest         0.030897
#  Mangamba forest         0.029709
#  Maramba gravity spri    0.027926
#  Name: Tanga, dtype: float64]

# %%
mode_scheme_name_per_region = grab_top_value_of_each_series(series_iterab = series_iterab)
# Out:
# {'Arusha': ('Machumba estate pipe line', 0.062),
#  'Dar es Salaam': ('J', 0.3),
#  'Dodoma': ('Ntom', 0.027),
#  'Iringa': ("wanging'ombe water supply s", 0.059),
#  'Kagera': ('Kaisho/Isingiro w', 0.066),
#  'Kigoma': ('Mkongoro Two', 0.084),
#  'Kilimanjaro': ("Uroki-Bomang'ombe water sup", 0.051),
#  'Lindi': ('GEN Borehole Scheme', 0.082),
#  'Manyara': ('Kijiji', 0.187),
#  'Mara': ('Mradi wa maji Komuge', 0.128),
#  'Mbeya': ('K', 0.286),
#  'Morogoro': ('Ki', 0.065),
#  'Mtwara': ('Borehole', 0.283),
#  'Mwanza': ('None', 0.248),
#  'Pwani': ('Chalinze wate', 0.354),
#  'Rukwa': ('K', 0.081),
#  'Ruvuma': ('DANIDA', 0.196),
#  'Shinyanga': ('None', 0.457),
#  'Singida': ('M', 0.181),
#  'Tabora': ('World Bank', 0.133),
#  'Tanga': ('Handeni Trunk Main(H', 0.082)}

# %%
Xy_train.groupby('region')
# Out:
# ['region']

# %%
Xy_train.groupby('region').scheme_name.value_counts()
# Out:
# region  scheme_name
# Arusha  Machumba estate pipe line         163
#         Maambreni gravity water supply    113
#         Nabaiye pipe line                  97
#         Nasula gravity water supply        95
#         Olkokola pipe line                 73
#                                          ...
# Tanga   TIRDO                               1
#         Underground water sc                1
#         Usambara Mountai                    1
#         Usambara Mountain                   1
#         Zahanati                            1
# Name: scheme_name, Length: 2689, dtype: int64

# %%
Xy_train.groupby('status_group')['amount_tsh'].describe().round(2)
# Out:
#                            count     mean      std   min    25%    50%  \
# status_group
# functional               11298.0  1179.64  6263.80  0.25   50.0  250.0
# functional needs repair   1142.0   917.35  3629.84  6.00  200.0  300.0
# non functional            3546.0   713.56  2684.34  0.20   50.0  200.0
#
#                             75%       max
# status_group
# functional               1000.0  350000.0
# functional needs repair   600.0  100000.0
# non functional            500.0  117000.0

# %% [markdown]
# Besides having 70 % of missing values amount_tsh has a very peculiar distribution, with a lot of potentially erroneous entries.
